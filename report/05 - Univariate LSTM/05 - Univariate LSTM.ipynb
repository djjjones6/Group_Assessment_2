# %% [markdown]
# # Single Variate LSTM Model

# %% [markdown]
# To explore the computational performance of our model, I will investigate whether a univariate LSTM model would be appropriate. Essentially, we would model the pollution at future time steps based solely on historical pollution data.
#
# We decided to explore this approach because, based on the correlation and lag data presented in our EDA, we hypothesize that pollution data—specifically from the previous time step—may be the most relevant predictor for our model. As we look into the scalability of our model, the goal is to reduce complexity to decrease computation time without sacrificing too much accuracy. Additionally, if we can eliminate irrelevant noise from the model, it will be highly beneficial.

# %%
import pickle
import numpy as np
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from keras.models import Sequential, load_model
from keras.layers import Dense, LSTM, Dropout, BatchNormalization, Input
from sklearn.metrics import mean_squared_error as mse
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import time
import tensorflow as tf

# %%
with open('../data/train_data.pickle', 'rb') as f:
    train_data = pickle.load(f)

# %%
with open('../data/test_data.pickle', 'rb') as f:
    test_data = pickle.load(f)

# %%
with open('../data/scaler_uv.pickle', 'rb') as f:
    scaler = pickle.load(f)

# %%
train_data = train_data['pollution']
test_data = test_data['pollution']
#convert to univariate

# %%
print(train_data.head())
print(test_data.head())
# Out:
# date
# 2010-01-02 00:00:00    0.129779
# 2010-01-02 01:00:00    0.148893
# 2010-01-02 02:00:00    0.159960
# 2010-01-02 03:00:00    0.182093
# 2010-01-02 04:00:00    0.138833
# Name: pollution, dtype: float64
# date
# 2014-07-02 12:00:00    0.056338
# 2014-07-02 13:00:00    0.064386
# 2014-07-02 14:00:00    0.066398
# 2014-07-02 15:00:00    0.072435
# 2014-07-02 16:00:00    0.078471
# Name: pollution, dtype: float64

# %% [markdown]
# ## Moving window validation
# In LSTM models, regular cross-validation methods are not appropriate. This is because cross-validation assumes independence between data points, which does not hold for time series data. In time series models, past values are often highly relevant to predicting future values, as the data exhibits temporal dependencies. Additionally, with traditional cross-validation, there is a risk of data leakage. This occurs when the data is randomly split into training and testing sets, potentially allowing future information to influence the training process. This violates the temporal order of the data, where future values should not be used to predict past ones.
#
# Hence we will use moving window validation instead, which ensures data used when making predictions is only from past data

# %%
def create_sequences(data, sequence_length):
    sequences = []
    labels = []
    for i in range(len(data) - sequence_length):
        sequences.append(data.iloc[i:i+sequence_length].values)  # Sequence of pollution values
        labels.append(data.iloc[i + sequence_length])  # Next time step's pollution value (target)
    return np.array(sequences), np.array(labels)

X_train, y_train = create_sequences(train_data, 10)
X_test, y_test = create_sequences(test_data, 10)

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (39410, 10), y_train shape: (39410,)
# X_test shape: (4370, 10), y_test shape: (4370,)

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# ## Basic LSTM model
#
# To start with we will use a large number of epochs of 100, and then look to implement early stopping to improve training time and reduce overfitting. The rest of the hyperparameters chosen are pretty standard when it comes to LSTM models which I will look at adjusting a few later on in relation to improving computation time and GPU performance. For instance batch size will be investigated, which is the number samples of data in a mini batch, which the model does a forward and backward pass on in each epoch.

# %% [markdown]
# Throughout our testing of the models, we will evaluate performance based on both loss (training and validation loss, using mean squared error) and RMSE. Additionally, we will assess GPU performance and training time to draw conclusions about the impact of different modifications to the model.

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# This is due to looking at the hardware requirements for using GPUs on tensorflow on https://www.tensorflow.org/install/pip#windows-native we can see that there is "There is currently no official GPU support for MacOS". As I can not install tensorflow-metal, I will continue to conduct analysis using the version running on CPU, looking at the CPU performance.

# %% [markdown]
# Although I will only be looking at CPU training time, Matt who can use a GPU will test GPU performance using my final model.

# %%
# Set random seed for reproducibility, same seed used in mulitvariate LSTM for comparison
tf.random.set_seed(7)


model = Sequential()
model.add(Input(shape=(X_train.shape[1], 1)))  
model.add(LSTM(units=50, return_sequences=False)) #return_sequences = False used, common in time series prediction and non-stacked models
model.add(Dense(1))

model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error', metrics=[RootMeanSquaredError()])

initial_weights = model.get_weights()

start_time = time.time()

# Train the model
history = model.fit(
    X_train, y_train, 
    epochs=100,                  
    batch_size=64,                
    validation_data=(X_test, y_test)
)

# Output the training time
print("Training Time: ", time.time() - start_time)

# Plot training and validation loss over epochs
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0032 - root_mean_squared_error: 0.0545 - val_loss: 6.9280e-04 - val_root_mean_squared_error: 0.0263
# Epoch 2/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.1668e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.2888e-04 - val_root_mean_squared_error: 0.0230
# Epoch 3/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.0281e-04 - root_mean_squared_error: 0.0283 - val_loss: 5.0920e-04 - val_root_mean_squared_error: 0.0226
# Epoch 4/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.7859e-04 - root_mean_squared_error: 0.0279 - val_loss: 5.1687e-04 - val_root_mean_squared_error: 0.0227
# Epoch 5/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.6896e-04 - root_mean_squared_error: 0.0277 - val_loss: 5.1614e-04 - val_root_mean_squared_error: 0.0227
# Epoch 6/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.6441e-04 - root_mean_squared_error: 0.0276 - val_loss: 5.1025e-04 - val_root_mean_squared_error: 0.0226
# Epoch 7/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.6170e-04 - root_mean_squared_error: 0.0276 - val_loss: 5.0413e-04 - val_root_mean_squared_error: 0.0225
# Epoch 8/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5997e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9943e-04 - val_root_mean_squared_error: 0.0223
# Epoch 9/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5886e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9634e-04 - val_root_mean_squared_error: 0.0223
# Epoch 10/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5817e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9444e-04 - val_root_mean_squared_error: 0.0222
# Epoch 11/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5774e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9323e-04 - val_root_mean_squared_error: 0.0222
# Epoch 12/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5746e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9237e-04 - val_root_mean_squared_error: 0.0222
# Epoch 13/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 7.5725e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9179e-04 - val_root_mean_squared_error: 0.0222
# Epoch 14/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 7.5707e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9153e-04 - val_root_mean_squared_error: 0.0222
# Epoch 15/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5690e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9169e-04 - val_root_mean_squared_error: 0.0222
# Epoch 16/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5672e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9147e-04 - val_root_mean_squared_error: 0.0222
# Epoch 17/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5650e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9118e-04 - val_root_mean_squared_error: 0.0222
# Epoch 18/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.5626e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9095e-04 - val_root_mean_squared_error: 0.0222
# Epoch 19/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 7.5599e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9126e-04 - val_root_mean_squared_error: 0.0222
# Epoch 20/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5575e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9088e-04 - val_root_mean_squared_error: 0.0222
# Epoch 21/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5543e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9083e-04 - val_root_mean_squared_error: 0.0222
# Epoch 22/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5512e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9093e-04 - val_root_mean_squared_error: 0.0222
# Epoch 23/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5482e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9085e-04 - val_root_mean_squared_error: 0.0222
# Epoch 24/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5452e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9099e-04 - val_root_mean_squared_error: 0.0222
# Epoch 25/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 7.5420e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9064e-04 - val_root_mean_squared_error: 0.0222
# Epoch 26/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5384e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9044e-04 - val_root_mean_squared_error: 0.0221
# Epoch 27/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5346e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9103e-04 - val_root_mean_squared_error: 0.0222
# Epoch 28/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5326e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9036e-04 - val_root_mean_squared_error: 0.0221
# Epoch 29/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5282e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9030e-04 - val_root_mean_squared_error: 0.0221
# Epoch 30/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 7.5248e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9021e-04 - val_root_mean_squared_error: 0.0221
# Epoch 31/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 7.5210e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9022e-04 - val_root_mean_squared_error: 0.0221
# Epoch 32/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5188e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9020e-04 - val_root_mean_squared_error: 0.0221
# Epoch 33/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5151e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9021e-04 - val_root_mean_squared_error: 0.0221
# Epoch 34/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5123e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9005e-04 - val_root_mean_squared_error: 0.0221
# Epoch 35/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5089e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.8999e-04 - val_root_mean_squared_error: 0.0221
# Epoch 36/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5051e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.8995e-04 - val_root_mean_squared_error: 0.0221
# Epoch 37/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5014e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.8991e-04 - val_root_mean_squared_error: 0.0221
# Epoch 38/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.4982e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.8986e-04 - val_root_mean_squared_error: 0.0221
# Epoch 39/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.4948e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.8980e-04 - val_root_mean_squared_error: 0.0221
# Epoch 40/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.4913e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.8980e-04 - val_root_mean_squared_error: 0.0221
# Epoch 41/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.4883e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.8975e-04 - val_root_mean_squared_error: 0.0221
# Epoch 42/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.4838e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.8974e-04 - val_root_mean_squared_error: 0.0221
# Epoch 43/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4801e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.8971e-04 - val_root_mean_squared_error: 0.0221
# Epoch 44/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4767e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.8969e-04 - val_root_mean_squared_error: 0.0221
# Epoch 45/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4724e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.8969e-04 - val_root_mean_squared_error: 0.0221
# Epoch 46/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4677e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.8969e-04 - val_root_mean_squared_error: 0.0221
# Epoch 47/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4632e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.8972e-04 - val_root_mean_squared_error: 0.0221
# Epoch 48/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4582e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.8975e-04 - val_root_mean_squared_error: 0.0221
# Epoch 49/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4525e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.8978e-04 - val_root_mean_squared_error: 0.0221
# Epoch 50/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4467e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.8985e-04 - val_root_mean_squared_error: 0.0221
# Epoch 51/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4403e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.8993e-04 - val_root_mean_squared_error: 0.0221
# Epoch 52/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4335e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.9002e-04 - val_root_mean_squared_error: 0.0221
# Epoch 53/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4264e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.9013e-04 - val_root_mean_squared_error: 0.0221
# Epoch 54/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4190e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.9027e-04 - val_root_mean_squared_error: 0.0221
# Epoch 55/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4114e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.9042e-04 - val_root_mean_squared_error: 0.0221
# Epoch 56/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4037e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.9058e-04 - val_root_mean_squared_error: 0.0221
# Epoch 57/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3959e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.9073e-04 - val_root_mean_squared_error: 0.0222
# Epoch 58/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3880e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.9087e-04 - val_root_mean_squared_error: 0.0222
# Epoch 59/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3802e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9100e-04 - val_root_mean_squared_error: 0.0222
# Epoch 60/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3724e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9111e-04 - val_root_mean_squared_error: 0.0222
# Epoch 61/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3645e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9121e-04 - val_root_mean_squared_error: 0.0222
# Epoch 62/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3565e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9129e-04 - val_root_mean_squared_error: 0.0222
# Epoch 63/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3484e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9135e-04 - val_root_mean_squared_error: 0.0222
# Epoch 64/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3400e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9141e-04 - val_root_mean_squared_error: 0.0222
# Epoch 65/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3313e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9145e-04 - val_root_mean_squared_error: 0.0222
# Epoch 66/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3224e-04 - root_mean_squared_error: 0.0270 - val_loss: 4.9148e-04 - val_root_mean_squared_error: 0.0222
# Epoch 67/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3132e-04 - root_mean_squared_error: 0.0270 - val_loss: 4.9150e-04 - val_root_mean_squared_error: 0.0222
# Epoch 68/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3038e-04 - root_mean_squared_error: 0.0270 - val_loss: 4.9148e-04 - val_root_mean_squared_error: 0.0222
# Epoch 69/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2941e-04 - root_mean_squared_error: 0.0270 - val_loss: 4.9145e-04 - val_root_mean_squared_error: 0.0222
# Epoch 70/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2843e-04 - root_mean_squared_error: 0.0270 - val_loss: 4.9138e-04 - val_root_mean_squared_error: 0.0222
# Epoch 71/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2743e-04 - root_mean_squared_error: 0.0269 - val_loss: 4.9128e-04 - val_root_mean_squared_error: 0.0222
# Epoch 72/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2644e-04 - root_mean_squared_error: 0.0269 - val_loss: 4.9115e-04 - val_root_mean_squared_error: 0.0222
# Epoch 73/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2544e-04 - root_mean_squared_error: 0.0269 - val_loss: 4.9099e-04 - val_root_mean_squared_error: 0.0222
# Epoch 74/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2446e-04 - root_mean_squared_error: 0.0269 - val_loss: 4.9081e-04 - val_root_mean_squared_error: 0.0222
# Epoch 75/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2348e-04 - root_mean_squared_error: 0.0269 - val_loss: 4.9061e-04 - val_root_mean_squared_error: 0.0221
# Epoch 76/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2252e-04 - root_mean_squared_error: 0.0269 - val_loss: 4.9038e-04 - val_root_mean_squared_error: 0.0221
# Epoch 77/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2158e-04 - root_mean_squared_error: 0.0268 - val_loss: 4.9013e-04 - val_root_mean_squared_error: 0.0221
# Epoch 78/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2064e-04 - root_mean_squared_error: 0.0268 - val_loss: 4.8986e-04 - val_root_mean_squared_error: 0.0221
# Epoch 79/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1972e-04 - root_mean_squared_error: 0.0268 - val_loss: 4.8958e-04 - val_root_mean_squared_error: 0.0221
# Epoch 80/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1881e-04 - root_mean_squared_error: 0.0268 - val_loss: 4.8929e-04 - val_root_mean_squared_error: 0.0221
# Epoch 81/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1792e-04 - root_mean_squared_error: 0.0268 - val_loss: 4.8901e-04 - val_root_mean_squared_error: 0.0221
# Epoch 82/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1704e-04 - root_mean_squared_error: 0.0268 - val_loss: 4.8873e-04 - val_root_mean_squared_error: 0.0221
# Epoch 83/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1618e-04 - root_mean_squared_error: 0.0267 - val_loss: 4.8848e-04 - val_root_mean_squared_error: 0.0221
# Epoch 84/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1534e-04 - root_mean_squared_error: 0.0267 - val_loss: 4.8825e-04 - val_root_mean_squared_error: 0.0221
# Epoch 85/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1451e-04 - root_mean_squared_error: 0.0267 - val_loss: 4.8805e-04 - val_root_mean_squared_error: 0.0221
# Epoch 86/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1370e-04 - root_mean_squared_error: 0.0267 - val_loss: 4.8788e-04 - val_root_mean_squared_error: 0.0221
# Epoch 87/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1289e-04 - root_mean_squared_error: 0.0267 - val_loss: 4.8774e-04 - val_root_mean_squared_error: 0.0221
# Epoch 88/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1210e-04 - root_mean_squared_error: 0.0267 - val_loss: 4.8761e-04 - val_root_mean_squared_error: 0.0221
# Epoch 89/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1131e-04 - root_mean_squared_error: 0.0266 - val_loss: 4.8750e-04 - val_root_mean_squared_error: 0.0221
# Epoch 90/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1053e-04 - root_mean_squared_error: 0.0266 - val_loss: 4.8740e-04 - val_root_mean_squared_error: 0.0221
# Epoch 91/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.0976e-04 - root_mean_squared_error: 0.0266 - val_loss: 4.8730e-04 - val_root_mean_squared_error: 0.0221
# Epoch 92/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.0900e-04 - root_mean_squared_error: 0.0266 - val_loss: 4.8720e-04 - val_root_mean_squared_error: 0.0221
# Epoch 93/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.0824e-04 - root_mean_squared_error: 0.0266 - val_loss: 4.8709e-04 - val_root_mean_squared_error: 0.0221
# Epoch 94/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.0748e-04 - root_mean_squared_error: 0.0266 - val_loss: 4.8699e-04 - val_root_mean_squared_error: 0.0221
# Epoch 95/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.0671e-04 - root_mean_squared_error: 0.0266 - val_loss: 4.8687e-04 - val_root_mean_squared_error: 0.0221
# Epoch 96/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.0595e-04 - root_mean_squared_error: 0.0265 - val_loss: 4.8675e-04 - val_root_mean_squared_error: 0.0221
# Epoch 97/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.0517e-04 - root_mean_squared_error: 0.0265 - val_loss: 4.8662e-04 - val_root_mean_squared_error: 0.0221
# Epoch 98/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.0440e-04 - root_mean_squared_error: 0.0265 - val_loss: 4.8648e-04 - val_root_mean_squared_error: 0.0221
# Epoch 99/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.0361e-04 - root_mean_squared_error: 0.0265 - val_loss: 4.8633e-04 - val_root_mean_squared_error: 0.0221
# Epoch 100/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.0281e-04 - root_mean_squared_error: 0.0265 - val_loss: 4.8616e-04 - val_root_mean_squared_error: 0.0220
# Training Time:  217.0167841911316

# %% [markdown]
# ## Early Stopping

# %% [markdown]
# Lets see if we can reduce overfitting and training time.

# %%
model.set_weights(initial_weights)

early_stopping = EarlyStopping(
    monitor='val_loss',          # Metric to monitor (could be 'val_accuracy', 'val_loss', etc.)
    patience=10,                 # Number of epochs to wait for improvement before stopping
    restore_best_weights=True,   # Restore the model with the best weights after training ends
    verbose=1                    # Print messages when early stopping is triggered
)

start_time = time.time() #time taken for model to run
# Train the model with early stopping
history = model.fit(
    X_train, y_train, 
    epochs=100,                   # Max number of epochs
    batch_size=64,                # Batch size
    validation_data=(X_test, y_test),  # Validation data for early stopping to monitor
     callbacks=[early_stopping]    # Pass the early stopping callback
)
print("Training Time: ", time.time() - start_time)

plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0020 - root_mean_squared_error: 0.0435 - val_loss: 6.0162e-04 - val_root_mean_squared_error: 0.0245
# Epoch 2/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 8.1669e-04 - root_mean_squared_error: 0.0286 - val_loss: 5.2987e-04 - val_root_mean_squared_error: 0.0230
# Epoch 3/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.7149e-04 - root_mean_squared_error: 0.0277 - val_loss: 5.0679e-04 - val_root_mean_squared_error: 0.0225
# Epoch 4/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.6381e-04 - root_mean_squared_error: 0.0276 - val_loss: 5.0053e-04 - val_root_mean_squared_error: 0.0224
# Epoch 5/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.6090e-04 - root_mean_squared_error: 0.0276 - val_loss: 4.9801e-04 - val_root_mean_squared_error: 0.0223
# Epoch 6/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5944e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9624e-04 - val_root_mean_squared_error: 0.0223
# Epoch 7/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5859e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9474e-04 - val_root_mean_squared_error: 0.0222
# Epoch 8/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5803e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9361e-04 - val_root_mean_squared_error: 0.0222
# Epoch 9/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5762e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9281e-04 - val_root_mean_squared_error: 0.0222
# Epoch 10/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5730e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9227e-04 - val_root_mean_squared_error: 0.0222
# Epoch 11/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5704e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9192e-04 - val_root_mean_squared_error: 0.0222
# Epoch 12/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5682e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9168e-04 - val_root_mean_squared_error: 0.0222
# Epoch 13/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 7.5662e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9163e-04 - val_root_mean_squared_error: 0.0222
# Epoch 14/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5644e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9154e-04 - val_root_mean_squared_error: 0.0222
# Epoch 15/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5624e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9158e-04 - val_root_mean_squared_error: 0.0222
# Epoch 16/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5605e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9167e-04 - val_root_mean_squared_error: 0.0222
# Epoch 17/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5585e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9156e-04 - val_root_mean_squared_error: 0.0222
# Epoch 18/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5564e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9144e-04 - val_root_mean_squared_error: 0.0222
# Epoch 19/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5541e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9152e-04 - val_root_mean_squared_error: 0.0222
# Epoch 20/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5521e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9134e-04 - val_root_mean_squared_error: 0.0222
# Epoch 21/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5496e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9136e-04 - val_root_mean_squared_error: 0.0222
# Epoch 22/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5475e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9200e-04 - val_root_mean_squared_error: 0.0222
# Epoch 23/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5456e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9116e-04 - val_root_mean_squared_error: 0.0222
# Epoch 24/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5423e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9116e-04 - val_root_mean_squared_error: 0.0222
# Epoch 25/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5403e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9110e-04 - val_root_mean_squared_error: 0.0222
# Epoch 26/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5373e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9113e-04 - val_root_mean_squared_error: 0.0222
# Epoch 27/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5360e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9109e-04 - val_root_mean_squared_error: 0.0222
# Epoch 28/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5331e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9123e-04 - val_root_mean_squared_error: 0.0222
# Epoch 29/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5313e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9113e-04 - val_root_mean_squared_error: 0.0222
# Epoch 30/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5287e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9105e-04 - val_root_mean_squared_error: 0.0222
# Epoch 31/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5261e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9110e-04 - val_root_mean_squared_error: 0.0222
# Epoch 32/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5243e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9107e-04 - val_root_mean_squared_error: 0.0222
# Epoch 33/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5210e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9104e-04 - val_root_mean_squared_error: 0.0222
# Epoch 34/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5179e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9104e-04 - val_root_mean_squared_error: 0.0222
# Epoch 35/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5154e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9107e-04 - val_root_mean_squared_error: 0.0222
# Epoch 36/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5130e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9106e-04 - val_root_mean_squared_error: 0.0222
# Epoch 37/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5091e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9110e-04 - val_root_mean_squared_error: 0.0222
# Epoch 38/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5059e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9110e-04 - val_root_mean_squared_error: 0.0222
# Epoch 39/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5021e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9117e-04 - val_root_mean_squared_error: 0.0222
# Epoch 40/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.4981e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9123e-04 - val_root_mean_squared_error: 0.0222
# Epoch 41/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4937e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.9129e-04 - val_root_mean_squared_error: 0.0222
# Epoch 42/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4885e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.9138e-04 - val_root_mean_squared_error: 0.0222
# Epoch 43/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.4828e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.9149e-04 - val_root_mean_squared_error: 0.0222
# Epoch 44/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4762e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.9161e-04 - val_root_mean_squared_error: 0.0222
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 34.
# Training Time:  95.76292777061462

# %% [markdown]
# As we can see, the number of optimal epochs is considered to be roughly to be 30( after running multiple times), reducing the training time to 95 seconds (for 44 epochs when early stopping occured) from 217 seconds.

# %%
test_predictions = model.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Train Predictions': test_predictions,
                                  'Actual':y_test.flatten()})
print(test_results)
# Out:
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#       Train Predictions    Actual
# 0              0.114858  0.101610
# 1              0.101944  0.111670
# 2              0.111865  0.110664
# 3              0.110518  0.134809
# 4              0.134466  0.170020
# ...                 ...       ...
# 4365           0.012533  0.008048
# 4366           0.010542  0.010060
# 4367           0.012644  0.010060
# 4368           0.012574  0.008048
# 4369           0.010534  0.012072
#
# [4370 rows x 2 columns]

# %%
plt.plot(test_results['Train Predictions'][:300], label='Predicted Values')
plt.plot(test_results['Actual'][:300], label='True Values')
plt.legend()
plt.show()

# %%
rmse = sqrt(mse(y_test, test_predictions))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.02216

# %% [markdown]
# This is just a plot on the standardised values, lets have a look at the inverse and compare results on the actual scale.

# %%
# Assume scaler is the same scaler used to normalize the data
# Reverse the scaling for both predictions and actual values

# Inverse transform for predicted values
test_predictions_scaled = scaler.inverse_transform(test_predictions.reshape(-1, 1)).flatten()

# Inverse transform for actual values (y_test)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()

# Create a DataFrame with actual vs predicted values
test_results = pd.DataFrame(data={'Train Predictions': test_predictions_scaled,
                                  'Actual': y_test_scaled})

# Print the results for a quick check
print(test_results.head())

# Plot the results
plt.figure(figsize=(10,6))
plt.plot(test_results['Train Predictions'][:300], label='Predicted Values')
plt.plot(test_results['Actual'][:300], label='True Values')
plt.legend()
plt.title('Predicted vs Actual Values (Inverse Transformed)')
plt.xlabel('Time Steps')
plt.ylabel('Pollution Level (Original Scale)')
plt.show()
# Out:
#    Train Predictions  Actual
# 0         114.168365   101.0
# 1         101.332176   111.0
# 2         111.193321   110.0
# 3         109.854607   134.0
# 4         133.658981   169.0

# %%
rmse = sqrt(mse(y_test_scaled, test_predictions_scaled))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 22.026

# %% [markdown]
# ## Batch size

# %% [markdown]
# Taking the number of epochs needed to be roughly 20, we will now test batch size to identify optimal CPU performance agaibst root mean square error.

# %%
batch_sizes=[16,32,64,128,256]
results = {"batch_size": [], "rmse":[], "cpu_time": []}

# %%
for batch_size in batch_sizes:
        model.set_weights(initial_weights)
        start_time = time.time()
        model.fit(X_train, y_train, epochs=30, batch_size=batch_size, validation_data=(X_test, y_test), shuffle=False)
        cpu_time = time.time() - start_time
        CPU_scores = model.evaluate(X_test, y_test)
        results["batch_size"].append(batch_size)
        results["rmse"].append(CPU_scores[1])
        results["cpu_time"].append(cpu_time)
# Out:
# Epoch 1/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0017 - root_mean_squared_error: 0.0397 - val_loss: 5.4412e-04 - val_root_mean_squared_error: 0.0233
# Epoch 2/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0010 - root_mean_squared_error: 0.0314 - val_loss: 5.4129e-04 - val_root_mean_squared_error: 0.0233
# Epoch 3/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0010 - root_mean_squared_error: 0.0314 - val_loss: 5.4410e-04 - val_root_mean_squared_error: 0.0233
# Epoch 4/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 9.9525e-04 - root_mean_squared_error: 0.0312 - val_loss: 5.4587e-04 - val_root_mean_squared_error: 0.0234
# Epoch 5/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 9.8594e-04 - root_mean_squared_error: 0.0311 - val_loss: 5.4645e-04 - val_root_mean_squared_error: 0.0234
# Epoch 6/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 9.7880e-04 - root_mean_squared_error: 0.0310 - val_loss: 5.4652e-04 - val_root_mean_squared_error: 0.0234
# Epoch 7/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 9.7293e-04 - root_mean_squared_error: 0.0309 - val_loss: 5.4589e-04 - val_root_mean_squared_error: 0.0234
# Epoch 8/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 9.6813e-04 - root_mean_squared_error: 0.0308 - val_loss: 5.4506e-04 - val_root_mean_squared_error: 0.0233
# Epoch 9/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 9.6420e-04 - root_mean_squared_error: 0.0308 - val_loss: 5.4424e-04 - val_root_mean_squared_error: 0.0233
# Epoch 10/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 9.6071e-04 - root_mean_squared_error: 0.0307 - val_loss: 5.4347e-04 - val_root_mean_squared_error: 0.0233
# Epoch 11/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.5779e-04 - root_mean_squared_error: 0.0307 - val_loss: 5.4273e-04 - val_root_mean_squared_error: 0.0233
# Epoch 12/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.5527e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.4215e-04 - val_root_mean_squared_error: 0.0233
# Epoch 13/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.5307e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.4156e-04 - val_root_mean_squared_error: 0.0233
# Epoch 14/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.5102e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.4091e-04 - val_root_mean_squared_error: 0.0233
# Epoch 15/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.4917e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.4023e-04 - val_root_mean_squared_error: 0.0232
# Epoch 16/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.4744e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.3952e-04 - val_root_mean_squared_error: 0.0232
# Epoch 17/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.4576e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.3885e-04 - val_root_mean_squared_error: 0.0232
# Epoch 18/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.4420e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.3811e-04 - val_root_mean_squared_error: 0.0232
# Epoch 19/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.4264e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.3741e-04 - val_root_mean_squared_error: 0.0232
# Epoch 20/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.4118e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.3684e-04 - val_root_mean_squared_error: 0.0232
# Epoch 21/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.3974e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.3630e-04 - val_root_mean_squared_error: 0.0232
# Epoch 22/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.3822e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.3563e-04 - val_root_mean_squared_error: 0.0231
# Epoch 23/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.3666e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.3491e-04 - val_root_mean_squared_error: 0.0231
# Epoch 24/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.3510e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.3419e-04 - val_root_mean_squared_error: 0.0231
# Epoch 25/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 9.3349e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.3352e-04 - val_root_mean_squared_error: 0.0231
# Epoch 26/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 9.3177e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.3297e-04 - val_root_mean_squared_error: 0.0231
# Epoch 27/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 9.2993e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.3223e-04 - val_root_mean_squared_error: 0.0231
# Epoch 28/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 9.2797e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.3145e-04 - val_root_mean_squared_error: 0.0231
# Epoch 29/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 9.2585e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.3077e-04 - val_root_mean_squared_error: 0.0230
# Epoch 30/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 9.2353e-04 - root_mean_squared_error: 0.0301 - val_loss: 5.3020e-04 - val_root_mean_squared_error: 0.0230
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - loss: 3.2377e-04 - root_mean_squared_error: 0.0177
# Epoch 1/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0019 - root_mean_squared_error: 0.0419 - val_loss: 5.3641e-04 - val_root_mean_squared_error: 0.0232
# Epoch 2/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.7873e-04 - root_mean_squared_error: 0.0310 - val_loss: 5.0600e-04 - val_root_mean_squared_error: 0.0225
# Epoch 3/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0010 - root_mean_squared_error: 0.0313 - val_loss: 5.0657e-04 - val_root_mean_squared_error: 0.0225
# Epoch 4/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.9915e-04 - root_mean_squared_error: 0.0313 - val_loss: 5.0798e-04 - val_root_mean_squared_error: 0.0225
# Epoch 5/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.9177e-04 - root_mean_squared_error: 0.0311 - val_loss: 5.0924e-04 - val_root_mean_squared_error: 0.0226
# Epoch 6/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.8469e-04 - root_mean_squared_error: 0.0310 - val_loss: 5.1016e-04 - val_root_mean_squared_error: 0.0226
# Epoch 7/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.7830e-04 - root_mean_squared_error: 0.0310 - val_loss: 5.1072e-04 - val_root_mean_squared_error: 0.0226
# Epoch 8/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.7266e-04 - root_mean_squared_error: 0.0309 - val_loss: 5.1101e-04 - val_root_mean_squared_error: 0.0226
# Epoch 9/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.6773e-04 - root_mean_squared_error: 0.0308 - val_loss: 5.1110e-04 - val_root_mean_squared_error: 0.0226
# Epoch 10/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 9.6337e-04 - root_mean_squared_error: 0.0307 - val_loss: 5.1101e-04 - val_root_mean_squared_error: 0.0226
# Epoch 11/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.5948e-04 - root_mean_squared_error: 0.0307 - val_loss: 5.1078e-04 - val_root_mean_squared_error: 0.0226
# Epoch 12/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.5607e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.1041e-04 - val_root_mean_squared_error: 0.0226
# Epoch 13/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.5298e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.1000e-04 - val_root_mean_squared_error: 0.0226
# Epoch 14/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.5017e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.0957e-04 - val_root_mean_squared_error: 0.0226
# Epoch 15/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.4765e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.0912e-04 - val_root_mean_squared_error: 0.0226
# Epoch 16/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.4536e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.0877e-04 - val_root_mean_squared_error: 0.0226
# Epoch 17/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.4325e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.0845e-04 - val_root_mean_squared_error: 0.0225
# Epoch 18/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.4134e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.0810e-04 - val_root_mean_squared_error: 0.0225
# Epoch 19/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.3960e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.0774e-04 - val_root_mean_squared_error: 0.0225
# Epoch 20/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.3800e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.0738e-04 - val_root_mean_squared_error: 0.0225
# Epoch 21/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.3648e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0703e-04 - val_root_mean_squared_error: 0.0225
# Epoch 22/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.3505e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0667e-04 - val_root_mean_squared_error: 0.0225
# Epoch 23/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.3370e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0629e-04 - val_root_mean_squared_error: 0.0225
# Epoch 24/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.3240e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0591e-04 - val_root_mean_squared_error: 0.0225
# Epoch 25/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.3117e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0556e-04 - val_root_mean_squared_error: 0.0225
# Epoch 26/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.2996e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.0520e-04 - val_root_mean_squared_error: 0.0225
# Epoch 27/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.2878e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.0488e-04 - val_root_mean_squared_error: 0.0225
# Epoch 28/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 9.2764e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.0454e-04 - val_root_mean_squared_error: 0.0225
# Epoch 29/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 9.2652e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.0425e-04 - val_root_mean_squared_error: 0.0225
# Epoch 30/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 9.2537e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.0400e-04 - val_root_mean_squared_error: 0.0224
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0174e-04 - root_mean_squared_error: 0.0171
# Epoch 1/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0020 - root_mean_squared_error: 0.0433 - val_loss: 5.7525e-04 - val_root_mean_squared_error: 0.0240
# Epoch 2/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.7657e-04 - root_mean_squared_error: 0.0310 - val_loss: 5.0769e-04 - val_root_mean_squared_error: 0.0225
# Epoch 3/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.7121e-04 - root_mean_squared_error: 0.0309 - val_loss: 4.9589e-04 - val_root_mean_squared_error: 0.0223
# Epoch 4/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.7538e-04 - root_mean_squared_error: 0.0309 - val_loss: 4.9371e-04 - val_root_mean_squared_error: 0.0222
# Epoch 5/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.7376e-04 - root_mean_squared_error: 0.0309 - val_loss: 4.9363e-04 - val_root_mean_squared_error: 0.0222
# Epoch 6/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.7050e-04 - root_mean_squared_error: 0.0308 - val_loss: 4.9401e-04 - val_root_mean_squared_error: 0.0222
# Epoch 7/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 9.6691e-04 - root_mean_squared_error: 0.0308 - val_loss: 4.9440e-04 - val_root_mean_squared_error: 0.0222
# Epoch 8/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.6337e-04 - root_mean_squared_error: 0.0307 - val_loss: 4.9471e-04 - val_root_mean_squared_error: 0.0222
# Epoch 9/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.6000e-04 - root_mean_squared_error: 0.0307 - val_loss: 4.9489e-04 - val_root_mean_squared_error: 0.0222
# Epoch 10/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 9.5684e-04 - root_mean_squared_error: 0.0306 - val_loss: 4.9496e-04 - val_root_mean_squared_error: 0.0222
# Epoch 11/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 9.5386e-04 - root_mean_squared_error: 0.0306 - val_loss: 4.9500e-04 - val_root_mean_squared_error: 0.0222
# Epoch 12/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.5108e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.9493e-04 - val_root_mean_squared_error: 0.0222
# Epoch 13/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 9.4852e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.9491e-04 - val_root_mean_squared_error: 0.0222
# Epoch 14/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 9.4616e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.9470e-04 - val_root_mean_squared_error: 0.0222
# Epoch 15/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.4398e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.9472e-04 - val_root_mean_squared_error: 0.0222
# Epoch 16/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.4203e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.9445e-04 - val_root_mean_squared_error: 0.0222
# Epoch 17/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.4018e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.9444e-04 - val_root_mean_squared_error: 0.0222
# Epoch 18/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.3847e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.9426e-04 - val_root_mean_squared_error: 0.0222
# Epoch 19/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 9.3691e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.9416e-04 - val_root_mean_squared_error: 0.0222
# Epoch 20/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 9.3544e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.9401e-04 - val_root_mean_squared_error: 0.0222
# Epoch 21/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.3406e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.9387e-04 - val_root_mean_squared_error: 0.0222
# Epoch 22/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.3272e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.9378e-04 - val_root_mean_squared_error: 0.0222
# Epoch 23/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.3147e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.9365e-04 - val_root_mean_squared_error: 0.0222
# Epoch 24/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.3030e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.9355e-04 - val_root_mean_squared_error: 0.0222
# Epoch 25/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.2919e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.9345e-04 - val_root_mean_squared_error: 0.0222
# Epoch 26/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.2811e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.9334e-04 - val_root_mean_squared_error: 0.0222
# Epoch 27/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 9.2710e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.9327e-04 - val_root_mean_squared_error: 0.0222
# Epoch 28/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.2615e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.9320e-04 - val_root_mean_squared_error: 0.0222
# Epoch 29/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 9.2521e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.9316e-04 - val_root_mean_squared_error: 0.0222
# Epoch 30/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 9.2429e-04 - root_mean_squared_error: 0.0301 - val_loss: 4.9308e-04 - val_root_mean_squared_error: 0.0222
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.9314e-04 - root_mean_squared_error: 0.0169
# Epoch 1/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0027 - root_mean_squared_error: 0.0500 - val_loss: 6.9108e-04 - val_root_mean_squared_error: 0.0263
# Epoch 2/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0011 - root_mean_squared_error: 0.0324 - val_loss: 5.6375e-04 - val_root_mean_squared_error: 0.0237
# Epoch 3/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.7172e-04 - root_mean_squared_error: 0.0310 - val_loss: 5.1851e-04 - val_root_mean_squared_error: 0.0228
# Epoch 4/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.5572e-04 - root_mean_squared_error: 0.0307 - val_loss: 5.0169e-04 - val_root_mean_squared_error: 0.0224
# Epoch 5/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.5783e-04 - root_mean_squared_error: 0.0307 - val_loss: 4.9411e-04 - val_root_mean_squared_error: 0.0222
# Epoch 6/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.5937e-04 - root_mean_squared_error: 0.0307 - val_loss: 4.9096e-04 - val_root_mean_squared_error: 0.0222
# Epoch 7/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.5873e-04 - root_mean_squared_error: 0.0307 - val_loss: 4.8952e-04 - val_root_mean_squared_error: 0.0221
# Epoch 8/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.5709e-04 - root_mean_squared_error: 0.0306 - val_loss: 4.8874e-04 - val_root_mean_squared_error: 0.0221
# Epoch 9/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.5515e-04 - root_mean_squared_error: 0.0306 - val_loss: 4.8826e-04 - val_root_mean_squared_error: 0.0221
# Epoch 10/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.5317e-04 - root_mean_squared_error: 0.0306 - val_loss: 4.8793e-04 - val_root_mean_squared_error: 0.0221
# Epoch 11/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.5124e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.8767e-04 - val_root_mean_squared_error: 0.0221
# Epoch 12/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.4937e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.8745e-04 - val_root_mean_squared_error: 0.0221
# Epoch 13/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.4756e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.8725e-04 - val_root_mean_squared_error: 0.0221
# Epoch 14/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.4579e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.8708e-04 - val_root_mean_squared_error: 0.0221
# Epoch 15/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.4407e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.8692e-04 - val_root_mean_squared_error: 0.0221
# Epoch 16/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.4241e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.8678e-04 - val_root_mean_squared_error: 0.0221
# Epoch 17/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.4079e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.8666e-04 - val_root_mean_squared_error: 0.0221
# Epoch 18/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.3924e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.8656e-04 - val_root_mean_squared_error: 0.0221
# Epoch 19/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.3775e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.8648e-04 - val_root_mean_squared_error: 0.0221
# Epoch 20/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.3633e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.8642e-04 - val_root_mean_squared_error: 0.0221
# Epoch 21/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.3497e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.8638e-04 - val_root_mean_squared_error: 0.0221
# Epoch 22/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 9.3366e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.8636e-04 - val_root_mean_squared_error: 0.0221
# Epoch 23/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.3242e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.8635e-04 - val_root_mean_squared_error: 0.0221
# Epoch 24/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.3123e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.8636e-04 - val_root_mean_squared_error: 0.0221
# Epoch 25/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.3009e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.8637e-04 - val_root_mean_squared_error: 0.0221
# Epoch 26/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 9.2900e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.8639e-04 - val_root_mean_squared_error: 0.0221
# Epoch 27/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 9.2796e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.8642e-04 - val_root_mean_squared_error: 0.0221
# Epoch 28/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 9.2696e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.8643e-04 - val_root_mean_squared_error: 0.0221
# Epoch 29/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 9.2601e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.8645e-04 - val_root_mean_squared_error: 0.0221
# Epoch 30/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 9.2509e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.8647e-04 - val_root_mean_squared_error: 0.0221
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 812us/step - loss: 2.8903e-04 - root_mean_squared_error: 0.0168
# Epoch 1/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0034 - root_mean_squared_error: 0.0564 - val_loss: 9.0084e-04 - val_root_mean_squared_error: 0.0300
# Epoch 2/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0012 - root_mean_squared_error: 0.0342 - val_loss: 6.9167e-04 - val_root_mean_squared_error: 0.0263
# Epoch 3/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0010 - root_mean_squared_error: 0.0320 - val_loss: 6.0788e-04 - val_root_mean_squared_error: 0.0247
# Epoch 4/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.7594e-04 - root_mean_squared_error: 0.0311 - val_loss: 5.5094e-04 - val_root_mean_squared_error: 0.0235
# Epoch 5/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.5402e-04 - root_mean_squared_error: 0.0307 - val_loss: 5.2840e-04 - val_root_mean_squared_error: 0.0230
# Epoch 6/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.5252e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.2645e-04 - val_root_mean_squared_error: 0.0229
# Epoch 7/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.5557e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.2387e-04 - val_root_mean_squared_error: 0.0229
# Epoch 8/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.5641e-04 - root_mean_squared_error: 0.0307 - val_loss: 5.1983e-04 - val_root_mean_squared_error: 0.0228
# Epoch 9/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.5569e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.1660e-04 - val_root_mean_squared_error: 0.0227
# Epoch 10/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.5436e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.1422e-04 - val_root_mean_squared_error: 0.0227
# Epoch 11/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.5283e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.1242e-04 - val_root_mean_squared_error: 0.0226
# Epoch 12/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.5128e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.1100e-04 - val_root_mean_squared_error: 0.0226
# Epoch 13/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.4976e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.0987e-04 - val_root_mean_squared_error: 0.0226
# Epoch 14/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.4831e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.0895e-04 - val_root_mean_squared_error: 0.0226
# Epoch 15/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.4693e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.0819e-04 - val_root_mean_squared_error: 0.0225
# Epoch 16/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.4562e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.0757e-04 - val_root_mean_squared_error: 0.0225
# Epoch 17/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.4436e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.0706e-04 - val_root_mean_squared_error: 0.0225
# Epoch 18/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.4316e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.0665e-04 - val_root_mean_squared_error: 0.0225
# Epoch 19/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.4202e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.0631e-04 - val_root_mean_squared_error: 0.0225
# Epoch 20/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.4091e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.0604e-04 - val_root_mean_squared_error: 0.0225
# Epoch 21/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.3984e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.0583e-04 - val_root_mean_squared_error: 0.0225
# Epoch 22/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.3881e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.0566e-04 - val_root_mean_squared_error: 0.0225
# Epoch 23/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.3781e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.0554e-04 - val_root_mean_squared_error: 0.0225
# Epoch 24/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.3683e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0546e-04 - val_root_mean_squared_error: 0.0225
# Epoch 25/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.3588e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0541e-04 - val_root_mean_squared_error: 0.0225
# Epoch 26/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.3494e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0539e-04 - val_root_mean_squared_error: 0.0225
# Epoch 27/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.3403e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0540e-04 - val_root_mean_squared_error: 0.0225
# Epoch 28/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.3313e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0543e-04 - val_root_mean_squared_error: 0.0225
# Epoch 29/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.3226e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0548e-04 - val_root_mean_squared_error: 0.0225
# Epoch 30/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.3140e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0555e-04 - val_root_mean_squared_error: 0.0225
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 803us/step - loss: 3.0649e-04 - root_mean_squared_error: 0.0173

# %% [markdown]
# Now we will use these results to compare batch size with training time and rsme

# %%
fig, ax1 = plt.subplots()

# Plot CPU training time
ax1.set_xlabel('Batch Size')
ax1.set_ylabel('CPU Training Time (seconds)', color='tab:blue')
ax1.plot(results["batch_size"], results["cpu_time"], color='tab:blue', marker='o', label='CPU Training Time')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create second y-axis to plot RMSE
ax2 = ax1.twinx()
ax2.set_ylabel('RMSE', color='tab:orange')
ax2.plot(results["batch_size"], results["rmse"], color='tab:orange', marker='s', label='RMSE')
ax2.tick_params(axis='y', labelcolor='tab:orange')

# Show grid and title
plt.title('Comparison of CPU Training Time and RMSE for Different Batch Sizes')
ax1.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# As batch size 128 outputted the second best training time and best RMSE so we will use this batch size going forward. Any higher batch size will likely underfit the data set without having too much additional benefit to training time, as we can see with RSME increasing at 256 batch size.

# %% [markdown]
# ## Dropout layer

# %% [markdown]
# We will explore the use of using a dropout layer in our model to prevent overfitting. Based on our current results, the data does not seem to be overfitting as our test rsme has been lower than our training rsme so far, and the compelxity of our model is much lower due to it being univariate. However this process is a common method in LSTM modelling, so I will explore the useful of it.
#
# A dropout layer is a regularization technique in neural networks, input and recurrent connections to LSTM units are probabilistically excluded from activation forcing the to learn new patterns and generalise better to unseen data.

# %%
model.set_weights(initial_weights)
model.add(Dropout(0.2))

start_time = time.time() 
history = model.fit(
    X_train, y_train, 
    epochs=30,                   
    batch_size=128,                
    validation_data=(X_test, y_test))

print("Training Time: ", time.time() - start_time)
# Out:
# Epoch 1/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.0027 - root_mean_squared_error: 0.0499 - val_loss: 6.6194e-04 - val_root_mean_squared_error: 0.0257
# Epoch 2/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 8.9279e-04 - root_mean_squared_error: 0.0299 - val_loss: 5.4751e-04 - val_root_mean_squared_error: 0.0234
# Epoch 3/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.9626e-04 - root_mean_squared_error: 0.0282 - val_loss: 5.1126e-04 - val_root_mean_squared_error: 0.0226
# Epoch 4/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 7.7104e-04 - root_mean_squared_error: 0.0277 - val_loss: 5.0163e-04 - val_root_mean_squared_error: 0.0224
# Epoch 5/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.6330e-04 - root_mean_squared_error: 0.0276 - val_loss: 4.9820e-04 - val_root_mean_squared_error: 0.0223
# Epoch 6/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 7.5949e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9646e-04 - val_root_mean_squared_error: 0.0223
# Epoch 7/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5724e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9540e-04 - val_root_mean_squared_error: 0.0223
# Epoch 8/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5578e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9471e-04 - val_root_mean_squared_error: 0.0222
# Epoch 9/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5478e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9423e-04 - val_root_mean_squared_error: 0.0222
# Epoch 10/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5406e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9389e-04 - val_root_mean_squared_error: 0.0222
# Epoch 11/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 7.5353e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9365e-04 - val_root_mean_squared_error: 0.0222
# Epoch 12/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5312e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9347e-04 - val_root_mean_squared_error: 0.0222
# Epoch 13/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5280e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9334e-04 - val_root_mean_squared_error: 0.0222
# Epoch 14/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5254e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9323e-04 - val_root_mean_squared_error: 0.0222
# Epoch 15/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5232e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9313e-04 - val_root_mean_squared_error: 0.0222
# Epoch 16/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5213e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9305e-04 - val_root_mean_squared_error: 0.0222
# Epoch 17/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5197e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9297e-04 - val_root_mean_squared_error: 0.0222
# Epoch 18/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5182e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9290e-04 - val_root_mean_squared_error: 0.0222
# Epoch 19/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5168e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9284e-04 - val_root_mean_squared_error: 0.0222
# Epoch 20/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5155e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9279e-04 - val_root_mean_squared_error: 0.0222
# Epoch 21/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5143e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9275e-04 - val_root_mean_squared_error: 0.0222
# Epoch 22/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5132e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9272e-04 - val_root_mean_squared_error: 0.0222
# Epoch 23/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5121e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9270e-04 - val_root_mean_squared_error: 0.0222
# Epoch 24/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5110e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9268e-04 - val_root_mean_squared_error: 0.0222
# Epoch 25/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5099e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9268e-04 - val_root_mean_squared_error: 0.0222
# Epoch 26/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5089e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9267e-04 - val_root_mean_squared_error: 0.0222
# Epoch 27/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5078e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9267e-04 - val_root_mean_squared_error: 0.0222
# Epoch 28/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5067e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9268e-04 - val_root_mean_squared_error: 0.0222
# Epoch 29/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5056e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9268e-04 - val_root_mean_squared_error: 0.0222
# Epoch 30/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.5044e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9269e-04 - val_root_mean_squared_error: 0.0222
# Training Time:  48.36468815803528

# %%
test_predictions = model.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Train Predictions': test_predictions,
                                  'Actual':y_test.flatten()})
print(test_results)
# Out:
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step
#       Train Predictions    Actual
# 0              0.113925  0.101610
# 1              0.100879  0.111670
# 2              0.110478  0.110664
# 3              0.109340  0.134809
# 4              0.133180  0.170020
# ...                 ...       ...
# 4365           0.012632  0.008048
# 4366           0.010675  0.010060
# 4367           0.012691  0.010060
# 4368           0.012690  0.008048
# 4369           0.010648  0.012072
#
# [4370 rows x 2 columns]

# %%
# Assume scaler is the same scaler used to normalize the data
# Reverse the scaling for both predictions and actual values

# Inverse transform for predicted values
test_predictions_scaled = scaler.inverse_transform(test_predictions.reshape(-1, 1)).flatten()

# Inverse transform for actual values (y_test)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()

# Create a DataFrame with actual vs predicted values
test_results = pd.DataFrame(data={'Train Predictions': test_predictions_scaled,
                                  'Actual': y_test_scaled})

# Print the results for a quick check
print(test_results.head())

# Plot the results
plt.figure(figsize=(10,6))
plt.plot(test_results['Train Predictions'][:300], label='Predicted Values')
plt.plot(test_results['Actual'][:300], label='True Values')
plt.legend()
plt.title('Predicted vs Actual Values (Inverse Transformed)')
plt.xlabel('Time Steps')
plt.ylabel('Pollution Level (Original Scale)')
plt.show()
# Out:
#    Train Predictions  Actual
# 0         113.241280   101.0
# 1         100.273399   111.0
# 2         109.814644   110.0
# 3         108.684387   134.0
# 4         132.380493   169.0

# %%
rmse = sqrt(mse(y_test, test_predictions))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.02220

# %%
rmse = sqrt(mse(y_test_scaled, test_predictions_scaled))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 22.063

# %% [markdown]
# The Dropout layer slightly increased our test RSME loss, indicating perhaps that the model was not overfitting.

# %% [markdown]
# We have a low test RMSE of 22.063 and training time of 48 seconds.

# %% [markdown]
# ## Stacked LSTM

# %%
stacked_LSTM = Sequential()
stacked_LSTM.add(Input(shape =(X_train.shape[1], 1)))
stacked_LSTM.add(LSTM(32,return_sequences=True))
stacked_LSTM.add(Dropout(0.2)) 
stacked_LSTM.add(LSTM(16, return_sequences=False))
stacked_LSTM.add(Dense(1)) 

stacked_LSTM.compile(optimizer=Adam(learning_rate = 0.001), loss='mse', metrics = [RootMeanSquaredError()])

start_time = time.time()

history = stacked_LSTM.fit(
    X_train, y_train, 
    epochs=30,                  
    batch_size=128,                
    validation_data=(X_test, y_test)
)

print("Training Time: ", time.time() - start_time)

plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

test_predictions = model.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Train Predictions': test_predictions,
                                  'Actual':y_test.flatten()})

test_predictions_scaled = scaler.inverse_transform(test_predictions.reshape(-1, 1)).flatten()

# Inverse transform for actual values (y_test)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()

# Create a DataFrame with actual vs predicted values
test_results = pd.DataFrame(data={'Train Predictions': test_predictions_scaled,
                                  'Actual': y_test_scaled})

# Print the results for a quick check
print(test_results.head())

# Plot the results
plt.figure(figsize=(10,6))
plt.plot(test_results['Train Predictions'][:400], label='Predicted Values')
plt.plot(test_results['Actual'][:400], label='True Values')
plt.legend()
plt.title('Predicted vs Actual Values (Inverse Transformed)')
plt.xlabel('Time Steps')
plt.ylabel('Pollution Level (Original Scale)')
plt.show()
# Out:
# Epoch 1/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 0.0044 - root_mean_squared_error: 0.0646 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0344
# Epoch 2/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0014 - root_mean_squared_error: 0.0377 - val_loss: 7.3617e-04 - val_root_mean_squared_error: 0.0271
# Epoch 3/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.0010 - root_mean_squared_error: 0.0319 - val_loss: 5.8190e-04 - val_root_mean_squared_error: 0.0241
# Epoch 4/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.8700e-04 - root_mean_squared_error: 0.0298 - val_loss: 5.3477e-04 - val_root_mean_squared_error: 0.0231
# Epoch 5/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 8.2211e-04 - root_mean_squared_error: 0.0286 - val_loss: 5.1192e-04 - val_root_mean_squared_error: 0.0226
# Epoch 6/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 8.1189e-04 - root_mean_squared_error: 0.0285 - val_loss: 5.1680e-04 - val_root_mean_squared_error: 0.0227
# Epoch 7/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 8.1117e-04 - root_mean_squared_error: 0.0284 - val_loss: 5.0658e-04 - val_root_mean_squared_error: 0.0225
# Epoch 8/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 8.1126e-04 - root_mean_squared_error: 0.0284 - val_loss: 5.0515e-04 - val_root_mean_squared_error: 0.0225
# Epoch 9/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.9795e-04 - root_mean_squared_error: 0.0282 - val_loss: 5.0814e-04 - val_root_mean_squared_error: 0.0225
# Epoch 10/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.9745e-04 - root_mean_squared_error: 0.0282 - val_loss: 5.0123e-04 - val_root_mean_squared_error: 0.0224
# Epoch 11/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.9513e-04 - root_mean_squared_error: 0.0282 - val_loss: 4.9631e-04 - val_root_mean_squared_error: 0.0223
# Epoch 12/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 8.0296e-04 - root_mean_squared_error: 0.0283 - val_loss: 4.9636e-04 - val_root_mean_squared_error: 0.0223
# Epoch 13/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.9161e-04 - root_mean_squared_error: 0.0281 - val_loss: 4.9503e-04 - val_root_mean_squared_error: 0.0222
# Epoch 14/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 8.0049e-04 - root_mean_squared_error: 0.0283 - val_loss: 4.9577e-04 - val_root_mean_squared_error: 0.0223
# Epoch 15/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.9245e-04 - root_mean_squared_error: 0.0281 - val_loss: 4.9314e-04 - val_root_mean_squared_error: 0.0222
# Epoch 16/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.8916e-04 - root_mean_squared_error: 0.0281 - val_loss: 4.9295e-04 - val_root_mean_squared_error: 0.0222
# Epoch 17/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.9964e-04 - root_mean_squared_error: 0.0283 - val_loss: 4.9332e-04 - val_root_mean_squared_error: 0.0222
# Epoch 18/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.8483e-04 - root_mean_squared_error: 0.0280 - val_loss: 4.9299e-04 - val_root_mean_squared_error: 0.0222
# Epoch 19/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.9101e-04 - root_mean_squared_error: 0.0281 - val_loss: 4.9049e-04 - val_root_mean_squared_error: 0.0221
# Epoch 20/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.8037e-04 - root_mean_squared_error: 0.0279 - val_loss: 4.9068e-04 - val_root_mean_squared_error: 0.0222
# Epoch 21/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.8444e-04 - root_mean_squared_error: 0.0280 - val_loss: 4.9105e-04 - val_root_mean_squared_error: 0.0222
# Epoch 22/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.8537e-04 - root_mean_squared_error: 0.0280 - val_loss: 4.9138e-04 - val_root_mean_squared_error: 0.0222
# Epoch 23/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.8101e-04 - root_mean_squared_error: 0.0279 - val_loss: 4.8928e-04 - val_root_mean_squared_error: 0.0221
# Epoch 24/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.7875e-04 - root_mean_squared_error: 0.0279 - val_loss: 4.8866e-04 - val_root_mean_squared_error: 0.0221
# Epoch 25/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 7.8720e-04 - root_mean_squared_error: 0.0280 - val_loss: 4.8802e-04 - val_root_mean_squared_error: 0.0221
# Epoch 26/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 7.7594e-04 - root_mean_squared_error: 0.0278 - val_loss: 4.8876e-04 - val_root_mean_squared_error: 0.0221
# Epoch 27/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.8494e-04 - root_mean_squared_error: 0.0280 - val_loss: 4.8593e-04 - val_root_mean_squared_error: 0.0220
# Epoch 28/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.8033e-04 - root_mean_squared_error: 0.0279 - val_loss: 4.8875e-04 - val_root_mean_squared_error: 0.0221
# Epoch 29/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.5971e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.8831e-04 - val_root_mean_squared_error: 0.0221
# Epoch 30/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 7.6899e-04 - root_mean_squared_error: 0.0277 - val_loss: 4.8555e-04 - val_root_mean_squared_error: 0.0220
# Training Time:  64.81382083892822
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#    Train Predictions  Actual
# 0         113.241280   101.0
# 1         100.273399   111.0
# 2         109.814644   110.0
# 3         108.684387   134.0
# 4         132.380493   169.0

# %%
rmse = sqrt(mse(y_test_scaled, test_predictions_scaled))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 22.063

# %% [markdown]
# Running a stacked model only increased training time whilst the RSME remained the same. I discuss why this may be the case in my conclusion.

# %% [markdown]
# I should note the the training times changed on different runs, and results shown will only be on the final run which was slower than usual (wifi perhaps?)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this notebook, I have explored the use of a single-variate LSTM model to assess whether we can reduce computational costs without sacrificing model performance. The results so far are very good, with the model performing well and achieving a low runtime, despite the lack of GPU support. This is encouraging for the scalability of our model, especially when considering larger datasets. When comparing the single-variate model with the multivariate model in future work, we will assess whether the dimensionality reduction was appropriate by identifying and potentially removing unnecessary noise.
#
# In Matt's notebook, we will further evaluate how the LSTM model compares to the multivariate approach using the GPU support available through `tensorflow-metal`.
#
# One of the key disadvantages of using LSTM models is their sequential nature, where each epoch is processed one at a time, limiting the potential for parallelization. For example, PySpark is not optimized for deep learning tasks, and therefore may not be well-suited for scaling our LSTM model. However, strategies such as minimizing the number of epochs, ensuring minimal training loss, and using large batch sizes (while avoiding overfitting) are essential for reducing training time, which were all used in this notebook.

# %% [markdown]
# Based on our EDA on partial autocorrelation, it suggested that only the previous time step is useful information to predict future values. So, when we used a stacked LSTM the one with more layers with the one that seemed to have same performance but its training time was higher, this could be just because we are adding unnecessary complexity on top of the model. The additional layers are made to capture long-range dependencies and complexity which may be unnecessary for this simple univariate data that doesn't seem to have long-range dependencies. Moreover, having `return_sequences=True` on the LSTM layers are not necessary, since it would keep all the hidden states. If the predictions only require the previous time step, this could slow down training and increase memory usage.
#
# For my model, adding complexity to the model for better loss performance may not be ideal but this might be useful for Matt with his multivariate model.
#
#
# On the contray, the model also appears to have some bias toward the mean (when looking at the extreme values of the graphs), which could be a sign of underfitting. This could be problematic when applying the model in the real world, as predicting high levels of pollution is crucial for prevention, rather than having an overly conservative model. This mean-bias could be due to a number of factors. Perhaps because we only have one feature, the model doesn't have enough data to capture the temporal dependencies, or there is a lack of variability or patterns available in the data. If we were to use only pollution data and no other metrics, one approach could be to include lag features (thus making the model multivariate). Another consideration could be adjusting the sequence length to be longer, e.g a day/24 hours. While this may seem counterintuitive based on our EDA of partial autocorrelation, it could allow the model to capture a longer range of temporal dependencies which may have been missed. This suggestion is supported by the EDA on autocorrelation instead, which had correlation of around 0.5 on time step t + 24. Also, adjusting the loss function from the mean squared error (which minimizes distance from the mean) to any other loss function could potentially solve the problem of model biasing towards the mean. In the pursuit of reducing training time, increasing the batch size might have had a negative effect with regard to underfitting.

# %% [markdown]
# ### Other Resources

# %% [markdown]
# Moving window validation: https://medium.com/@TheDataScience-ProF/understanding-timeseriessplit-cross-validation-for-time-series-data-4c232cc4f844#:~:text=TimeSeriesSplit%20Cross%2DValidation%20Overview&text=The%20dataset%20is%20split%20into,and%20evaluated%20on%20future%20data.
#
# considerations for optimising lstm performance: https://medium.com/@yousufdata/6-tips-to-tweak-your-lstm-bilstm-15fd02685c8#:~:text=Your%20LSTM%20should%20always%20have,error%20in%20your%20neural%20network.
#
# considerations for optimising training time: https://towardsdatascience.com/how-to-reduce-the-training-time-of-your-neural-network-from-hours-to-minutes-fe7533a3eec5
#
# pyspark suitability for lstm: https://datascience.stackexchange.com/questions/53089/how-to-implement-lstm-with-spark
#
# return_sequences : https://eitca.org/artificial-intelligence/eitc-ai-tff-tensorflow-fundamentals/natural-language-processing-with-tensorflow/long-short-term-memory-for-nlp/examination-review-long-short-term-memory-for-nlp/what-is-the-significance-of-setting-the-return_sequences-parameter-to-true-when-stacking-multiple-lstm-layers/
