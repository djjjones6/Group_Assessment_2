# %% [markdown]
# # Single Variate LSTM Model

# %% [markdown]
# To explore the computational performance of our model, I will investigate whether a univariate LSTM model would be appropriate. Essentially, we would model the pollution at future time steps based solely on historical pollution data.
#
# We decided to explore this approach because, based on the correlation and lag data presented in our EDA, we hypothesize that pollution data—specifically from the previous time step—may be the most relevant predictor for our model. As we look into the scalability of our model, the goal is to reduce complexity to decrease computation time without sacrificing too much accuracy. Additionally, if we can eliminate irrelevant noise from the model, it will be highly beneficial.

# %%
import pickle
import numpy as np
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from keras.models import Sequential, load_model
from keras.layers import Dense, LSTM, Dropout, BatchNormalization, Input
from sklearn.metrics import mean_squared_error as mse
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import time
import tensorflow as tf

# %%
with open('../data/train_data.pickle', 'rb') as f:
    train_data = pickle.load(f)

# %%
with open('../data/test_data.pickle', 'rb') as f:
    test_data = pickle.load(f)

# %%
with open('../data/scaler_uv.pickle', 'rb') as f:
    scaler = pickle.load(f)

# %%
train_data = train_data['pollution']
test_data = test_data['pollution']
#convert to univariate

# %%
print(train_data.head())
print(test_data.head())
# Out:
# date
# 2010-01-02 00:00:00    0.129779
# 2010-01-02 01:00:00    0.148893
# 2010-01-02 02:00:00    0.159960
# 2010-01-02 03:00:00    0.182093
# 2010-01-02 04:00:00    0.138833
# Name: pollution, dtype: float64
# date
# 2014-07-02 12:00:00    0.056338
# 2014-07-02 13:00:00    0.064386
# 2014-07-02 14:00:00    0.066398
# 2014-07-02 15:00:00    0.072435
# 2014-07-02 16:00:00    0.078471
# Name: pollution, dtype: float64

# %% [markdown]
# ## Moving window validation
# In LSTM models, regular cross-validation methods are not appropriate. This is because cross-validation assumes independence between data points, which does not hold for time series data. In time series models, past values are often highly relevant to predicting future values, as the data exhibits temporal dependencies. Additionally, with traditional cross-validation, there is a risk of data leakage. This occurs when the data is randomly split into training and testing sets, potentially allowing future information to influence the training process. This violates the temporal order of the data, where future values should not be used to predict past ones.
#
# Hence we will use moving window validation instead, which ensures data used when making predictions is only from past data

# %%
def create_sequences(data, sequence_length):
    sequences = []
    labels = []
    for i in range(len(data) - sequence_length):
        sequences.append(data.iloc[i:i+sequence_length].values)  # Sequence of pollution values
        labels.append(data.iloc[i + sequence_length])  # Next time step's pollution value (target)
    return np.array(sequences), np.array(labels)

X_train, y_train = create_sequences(train_data, 10)
X_test, y_test = create_sequences(test_data, 10)

print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (39410, 10), y_train shape: (39410,)
# X_test shape: (4370, 10), y_test shape: (4370,)

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# ## Basic LSTM model
#
# To start with we will use a large number of epochs of 100, and then look to implement early stopping to improve training time and reduce overfitting. The rest of the hyperparameters chosen are pretty standard when it comes to LSTM models which I will look at adjusting a few later on in relation to improving computation time and GPU performance. For instance batch size will be investigated, which is the number samples of data in a mini batch, which the model does a forward and backward pass on in each epoch.

# %% [markdown]
# Throughout our testing of the models, we will evaluate performance based on both loss (training and validation loss, using mean squared error) and RMSE. Additionally, we will assess GPU performance and training time to draw conclusions about the impact of different modifications to the model.

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# This is due to looking at the hardware requirements for using GPUs on tensorflow on https://www.tensorflow.org/install/pip#windows-native we can see that there is "There is currently no official GPU support for MacOS". As I can not install tensorflow-metal, I will continue to conduct analysis using the version running on CPU, looking at the CPU performance.

# %% [markdown]
# Although I will only be looking at CPU training time, Matt who can use a GPU will test GPU performance using my final model.

# %%
# Set random seed for reproducibility, same seed used in mulitvariate LSTM for comparison
tf.random.set_seed(7)


model = Sequential()
model.add(Input(shape=(X_train.shape[1], 1)))  
model.add(LSTM(units=50, return_sequences=False)) #return_sequences = False used, common in time series prediction and non-stacked models
model.add(Dense(1))

model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error', metrics=[RootMeanSquaredError()])

initial_weights = model.get_weights()

start_time = time.time()

# Train the model
history = model.fit(
    X_train, y_train, 
    epochs=100,                  
    batch_size=64,                
    validation_data=(X_test, y_test)
)

# Output the training time
print("Training Time: ", time.time() - start_time)

# Plot training and validation loss over epochs
plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0027 - root_mean_squared_error: 0.0508 - val_loss: 6.8544e-04 - val_root_mean_squared_error: 0.0262
# Epoch 2/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 8.8246e-04 - root_mean_squared_error: 0.0297 - val_loss: 5.2324e-04 - val_root_mean_squared_error: 0.0229
# Epoch 3/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.8469e-04 - root_mean_squared_error: 0.0280 - val_loss: 5.2013e-04 - val_root_mean_squared_error: 0.0228
# Epoch 4/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.6907e-04 - root_mean_squared_error: 0.0277 - val_loss: 5.1374e-04 - val_root_mean_squared_error: 0.0227
# Epoch 5/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.6435e-04 - root_mean_squared_error: 0.0276 - val_loss: 5.0756e-04 - val_root_mean_squared_error: 0.0225
# Epoch 6/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.6181e-04 - root_mean_squared_error: 0.0276 - val_loss: 5.0381e-04 - val_root_mean_squared_error: 0.0224
# Epoch 7/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.6026e-04 - root_mean_squared_error: 0.0275 - val_loss: 5.0122e-04 - val_root_mean_squared_error: 0.0224
# Epoch 8/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5929e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9916e-04 - val_root_mean_squared_error: 0.0223
# Epoch 9/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5867e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9753e-04 - val_root_mean_squared_error: 0.0223
# Epoch 10/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5825e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9624e-04 - val_root_mean_squared_error: 0.0223
# Epoch 11/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5796e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9518e-04 - val_root_mean_squared_error: 0.0223
# Epoch 12/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5774e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9441e-04 - val_root_mean_squared_error: 0.0222
# Epoch 13/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5757e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9363e-04 - val_root_mean_squared_error: 0.0222
# Epoch 14/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.5744e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9307e-04 - val_root_mean_squared_error: 0.0222
# Epoch 15/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5730e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9274e-04 - val_root_mean_squared_error: 0.0222
# Epoch 16/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5716e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9271e-04 - val_root_mean_squared_error: 0.0222
# Epoch 17/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5700e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9420e-04 - val_root_mean_squared_error: 0.0222
# Epoch 18/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5684e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9244e-04 - val_root_mean_squared_error: 0.0222
# Epoch 19/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5665e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9176e-04 - val_root_mean_squared_error: 0.0222
# Epoch 20/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5643e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9236e-04 - val_root_mean_squared_error: 0.0222
# Epoch 21/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5628e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9167e-04 - val_root_mean_squared_error: 0.0222
# Epoch 22/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5600e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9233e-04 - val_root_mean_squared_error: 0.0222
# Epoch 23/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5577e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9195e-04 - val_root_mean_squared_error: 0.0222
# Epoch 24/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5557e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9167e-04 - val_root_mean_squared_error: 0.0222
# Epoch 25/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5531e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9228e-04 - val_root_mean_squared_error: 0.0222
# Epoch 26/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5507e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9235e-04 - val_root_mean_squared_error: 0.0222
# Epoch 27/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5486e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9142e-04 - val_root_mean_squared_error: 0.0222
# Epoch 28/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5459e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9123e-04 - val_root_mean_squared_error: 0.0222
# Epoch 29/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5429e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9120e-04 - val_root_mean_squared_error: 0.0222
# Epoch 30/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5407e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9124e-04 - val_root_mean_squared_error: 0.0222
# Epoch 31/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5381e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9130e-04 - val_root_mean_squared_error: 0.0222
# Epoch 32/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5357e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9135e-04 - val_root_mean_squared_error: 0.0222
# Epoch 33/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5330e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9125e-04 - val_root_mean_squared_error: 0.0222
# Epoch 34/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5305e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9117e-04 - val_root_mean_squared_error: 0.0222
# Epoch 35/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5278e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9113e-04 - val_root_mean_squared_error: 0.0222
# Epoch 36/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5248e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9134e-04 - val_root_mean_squared_error: 0.0222
# Epoch 37/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5230e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9121e-04 - val_root_mean_squared_error: 0.0222
# Epoch 38/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5201e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9117e-04 - val_root_mean_squared_error: 0.0222
# Epoch 39/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5167e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9120e-04 - val_root_mean_squared_error: 0.0222
# Epoch 40/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5137e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9127e-04 - val_root_mean_squared_error: 0.0222
# Epoch 41/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5112e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9123e-04 - val_root_mean_squared_error: 0.0222
# Epoch 42/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5072e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9126e-04 - val_root_mean_squared_error: 0.0222
# Epoch 43/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5038e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9129e-04 - val_root_mean_squared_error: 0.0222
# Epoch 44/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5002e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9133e-04 - val_root_mean_squared_error: 0.0222
# Epoch 45/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4956e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9140e-04 - val_root_mean_squared_error: 0.0222
# Epoch 46/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4917e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.9142e-04 - val_root_mean_squared_error: 0.0222
# Epoch 47/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4868e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.9149e-04 - val_root_mean_squared_error: 0.0222
# Epoch 48/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4817e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.9157e-04 - val_root_mean_squared_error: 0.0222
# Epoch 49/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4760e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.9164e-04 - val_root_mean_squared_error: 0.0222
# Epoch 50/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4703e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.9173e-04 - val_root_mean_squared_error: 0.0222
# Epoch 51/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4633e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.9183e-04 - val_root_mean_squared_error: 0.0222
# Epoch 52/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4570e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.9191e-04 - val_root_mean_squared_error: 0.0222
# Epoch 53/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4492e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.9202e-04 - val_root_mean_squared_error: 0.0222
# Epoch 54/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4414e-04 - root_mean_squared_error: 0.0273 - val_loss: 4.9212e-04 - val_root_mean_squared_error: 0.0222
# Epoch 55/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4337e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.9224e-04 - val_root_mean_squared_error: 0.0222
# Epoch 56/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4259e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.9229e-04 - val_root_mean_squared_error: 0.0222
# Epoch 57/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4184e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.9236e-04 - val_root_mean_squared_error: 0.0222
# Epoch 58/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.4111e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.9237e-04 - val_root_mean_squared_error: 0.0222
# Epoch 59/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.4042e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.9239e-04 - val_root_mean_squared_error: 0.0222
# Epoch 60/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3975e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.9239e-04 - val_root_mean_squared_error: 0.0222
# Epoch 61/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3913e-04 - root_mean_squared_error: 0.0272 - val_loss: 4.9241e-04 - val_root_mean_squared_error: 0.0222
# Epoch 62/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.3850e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9237e-04 - val_root_mean_squared_error: 0.0222
# Epoch 63/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.3790e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9233e-04 - val_root_mean_squared_error: 0.0222
# Epoch 64/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.3728e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9227e-04 - val_root_mean_squared_error: 0.0222
# Epoch 65/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3668e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9220e-04 - val_root_mean_squared_error: 0.0222
# Epoch 66/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3606e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9212e-04 - val_root_mean_squared_error: 0.0222
# Epoch 67/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.3545e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9203e-04 - val_root_mean_squared_error: 0.0222
# Epoch 68/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.3482e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9193e-04 - val_root_mean_squared_error: 0.0222
# Epoch 69/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.3420e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9182e-04 - val_root_mean_squared_error: 0.0222
# Epoch 70/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.3355e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.9171e-04 - val_root_mean_squared_error: 0.0222
# Epoch 71/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.3289e-04 - root_mean_squared_error: 0.0270 - val_loss: 4.9158e-04 - val_root_mean_squared_error: 0.0222
# Epoch 72/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.3221e-04 - root_mean_squared_error: 0.0270 - val_loss: 4.9143e-04 - val_root_mean_squared_error: 0.0222
# Epoch 73/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3150e-04 - root_mean_squared_error: 0.0270 - val_loss: 4.9127e-04 - val_root_mean_squared_error: 0.0222
# Epoch 74/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.3075e-04 - root_mean_squared_error: 0.0270 - val_loss: 4.9110e-04 - val_root_mean_squared_error: 0.0222
# Epoch 75/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.2996e-04 - root_mean_squared_error: 0.0270 - val_loss: 4.9092e-04 - val_root_mean_squared_error: 0.0222
# Epoch 76/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.2913e-04 - root_mean_squared_error: 0.0270 - val_loss: 4.9073e-04 - val_root_mean_squared_error: 0.0222
# Epoch 77/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.2825e-04 - root_mean_squared_error: 0.0270 - val_loss: 4.9052e-04 - val_root_mean_squared_error: 0.0221
# Epoch 78/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.2733e-04 - root_mean_squared_error: 0.0269 - val_loss: 4.9029e-04 - val_root_mean_squared_error: 0.0221
# Epoch 79/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.2637e-04 - root_mean_squared_error: 0.0269 - val_loss: 4.9005e-04 - val_root_mean_squared_error: 0.0221
# Epoch 80/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2537e-04 - root_mean_squared_error: 0.0269 - val_loss: 4.8979e-04 - val_root_mean_squared_error: 0.0221
# Epoch 81/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.2435e-04 - root_mean_squared_error: 0.0269 - val_loss: 4.8950e-04 - val_root_mean_squared_error: 0.0221
# Epoch 82/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2331e-04 - root_mean_squared_error: 0.0269 - val_loss: 4.8919e-04 - val_root_mean_squared_error: 0.0221
# Epoch 83/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.2226e-04 - root_mean_squared_error: 0.0269 - val_loss: 4.8885e-04 - val_root_mean_squared_error: 0.0221
# Epoch 84/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2122e-04 - root_mean_squared_error: 0.0268 - val_loss: 4.8848e-04 - val_root_mean_squared_error: 0.0221
# Epoch 85/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.2020e-04 - root_mean_squared_error: 0.0268 - val_loss: 4.8809e-04 - val_root_mean_squared_error: 0.0221
# Epoch 86/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1921e-04 - root_mean_squared_error: 0.0268 - val_loss: 4.8768e-04 - val_root_mean_squared_error: 0.0221
# Epoch 87/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 7.1825e-04 - root_mean_squared_error: 0.0268 - val_loss: 4.8726e-04 - val_root_mean_squared_error: 0.0221
# Epoch 88/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.1734e-04 - root_mean_squared_error: 0.0268 - val_loss: 4.8685e-04 - val_root_mean_squared_error: 0.0221
# Epoch 89/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1647e-04 - root_mean_squared_error: 0.0267 - val_loss: 4.8645e-04 - val_root_mean_squared_error: 0.0221
# Epoch 90/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1564e-04 - root_mean_squared_error: 0.0267 - val_loss: 4.8607e-04 - val_root_mean_squared_error: 0.0220
# Epoch 91/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.1483e-04 - root_mean_squared_error: 0.0267 - val_loss: 4.8571e-04 - val_root_mean_squared_error: 0.0220
# Epoch 92/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.1406e-04 - root_mean_squared_error: 0.0267 - val_loss: 4.8536e-04 - val_root_mean_squared_error: 0.0220
# Epoch 93/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1330e-04 - root_mean_squared_error: 0.0267 - val_loss: 4.8504e-04 - val_root_mean_squared_error: 0.0220
# Epoch 94/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.1255e-04 - root_mean_squared_error: 0.0267 - val_loss: 4.8473e-04 - val_root_mean_squared_error: 0.0220
# Epoch 95/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1180e-04 - root_mean_squared_error: 0.0267 - val_loss: 4.8444e-04 - val_root_mean_squared_error: 0.0220
# Epoch 96/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1105e-04 - root_mean_squared_error: 0.0266 - val_loss: 4.8415e-04 - val_root_mean_squared_error: 0.0220
# Epoch 97/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.1029e-04 - root_mean_squared_error: 0.0266 - val_loss: 4.8387e-04 - val_root_mean_squared_error: 0.0220
# Epoch 98/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.0951e-04 - root_mean_squared_error: 0.0266 - val_loss: 4.8359e-04 - val_root_mean_squared_error: 0.0220
# Epoch 99/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 7.0870e-04 - root_mean_squared_error: 0.0266 - val_loss: 4.8331e-04 - val_root_mean_squared_error: 0.0220
# Epoch 100/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.0785e-04 - root_mean_squared_error: 0.0266 - val_loss: 4.8303e-04 - val_root_mean_squared_error: 0.0220
# Training Time:  221.26223015785217

# %% [markdown]
# ## Early Stopping

# %% [markdown]
# Lets see if we can reduce overfitting and training time.

# %%
model.set_weights(initial_weights)

early_stopping = EarlyStopping(
    monitor='val_loss',          # Metric to monitor (could be 'val_accuracy', 'val_loss', etc.)
    patience=10,                 # Number of epochs to wait for improvement before stopping
    restore_best_weights=True,   # Restore the model with the best weights after training ends
    verbose=1                    # Print messages when early stopping is triggered
)

start_time = time.time() #time taken for model to run
# Train the model with early stopping
history = model.fit(
    X_train, y_train, 
    epochs=100,                   # Max number of epochs
    batch_size=64,                # Batch size
    validation_data=(X_test, y_test),  # Validation data for early stopping to monitor
     callbacks=[early_stopping]    # Pass the early stopping callback
)
print("Training Time: ", time.time() - start_time)

plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.0018 - root_mean_squared_error: 0.0416 - val_loss: 5.7568e-04 - val_root_mean_squared_error: 0.0240
# Epoch 2/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 7.9871e-04 - root_mean_squared_error: 0.0282 - val_loss: 5.1542e-04 - val_root_mean_squared_error: 0.0227
# Epoch 3/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.6705e-04 - root_mean_squared_error: 0.0277 - val_loss: 5.0329e-04 - val_root_mean_squared_error: 0.0224
# Epoch 4/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.6234e-04 - root_mean_squared_error: 0.0276 - val_loss: 5.0054e-04 - val_root_mean_squared_error: 0.0224
# Epoch 5/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.6040e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9937e-04 - val_root_mean_squared_error: 0.0223
# Epoch 6/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 7.5927e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9839e-04 - val_root_mean_squared_error: 0.0223
# Epoch 7/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5856e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9743e-04 - val_root_mean_squared_error: 0.0223
# Epoch 8/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5809e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9654e-04 - val_root_mean_squared_error: 0.0223
# Epoch 9/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5778e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9577e-04 - val_root_mean_squared_error: 0.0223
# Epoch 10/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5757e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9512e-04 - val_root_mean_squared_error: 0.0223
# Epoch 11/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5742e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9456e-04 - val_root_mean_squared_error: 0.0222
# Epoch 12/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5730e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9406e-04 - val_root_mean_squared_error: 0.0222
# Epoch 13/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5719e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9368e-04 - val_root_mean_squared_error: 0.0222
# Epoch 14/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5708e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9332e-04 - val_root_mean_squared_error: 0.0222
# Epoch 15/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5696e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9291e-04 - val_root_mean_squared_error: 0.0222
# Epoch 16/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5682e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9271e-04 - val_root_mean_squared_error: 0.0222
# Epoch 17/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5667e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9294e-04 - val_root_mean_squared_error: 0.0222
# Epoch 18/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5651e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9240e-04 - val_root_mean_squared_error: 0.0222
# Epoch 19/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5634e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9242e-04 - val_root_mean_squared_error: 0.0222
# Epoch 20/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5617e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9213e-04 - val_root_mean_squared_error: 0.0222
# Epoch 21/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5599e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9255e-04 - val_root_mean_squared_error: 0.0222
# Epoch 22/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5580e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9193e-04 - val_root_mean_squared_error: 0.0222
# Epoch 23/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5560e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9184e-04 - val_root_mean_squared_error: 0.0222
# Epoch 24/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5539e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9180e-04 - val_root_mean_squared_error: 0.0222
# Epoch 25/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5520e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9194e-04 - val_root_mean_squared_error: 0.0222
# Epoch 26/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5501e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9165e-04 - val_root_mean_squared_error: 0.0222
# Epoch 27/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5480e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9138e-04 - val_root_mean_squared_error: 0.0222
# Epoch 28/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 7.5457e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9137e-04 - val_root_mean_squared_error: 0.0222
# Epoch 29/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 7.5440e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9143e-04 - val_root_mean_squared_error: 0.0222
# Epoch 30/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5423e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9124e-04 - val_root_mean_squared_error: 0.0222
# Epoch 31/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5395e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9131e-04 - val_root_mean_squared_error: 0.0222
# Epoch 32/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5380e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9123e-04 - val_root_mean_squared_error: 0.0222
# Epoch 33/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5355e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9122e-04 - val_root_mean_squared_error: 0.0222
# Epoch 34/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 7.5334e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9123e-04 - val_root_mean_squared_error: 0.0222
# Epoch 35/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5319e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9119e-04 - val_root_mean_squared_error: 0.0222
# Epoch 36/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5289e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9120e-04 - val_root_mean_squared_error: 0.0222
# Epoch 37/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5270e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9123e-04 - val_root_mean_squared_error: 0.0222
# Epoch 38/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5247e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9156e-04 - val_root_mean_squared_error: 0.0222
# Epoch 39/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5232e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9124e-04 - val_root_mean_squared_error: 0.0222
# Epoch 40/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5195e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9126e-04 - val_root_mean_squared_error: 0.0222
# Epoch 41/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5171e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9138e-04 - val_root_mean_squared_error: 0.0222
# Epoch 42/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5149e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9130e-04 - val_root_mean_squared_error: 0.0222
# Epoch 43/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5111e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9134e-04 - val_root_mean_squared_error: 0.0222
# Epoch 44/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 7.5075e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9138e-04 - val_root_mean_squared_error: 0.0222
# Epoch 45/100
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 7.5041e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9143e-04 - val_root_mean_squared_error: 0.0222
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 35.
# Training Time:  103.03393483161926

# %% [markdown]
# As we can see, the number of optimal epochs is considered to be roughly to be 30, reducing the training time to 59 seconds (for 40 epochs) from 146 seconds.

# %%
test_predictions = model.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Train Predictions': test_predictions,
                                  'Actual':y_test.flatten()})
print(test_results)
# Out:
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#       Train Predictions    Actual
# 0              0.114870  0.101610
# 1              0.101918  0.111670
# 2              0.111953  0.110664
# 3              0.110522  0.134809
# 4              0.134547  0.170020
# ...                 ...       ...
# 4365           0.012470  0.008048
# 4366           0.010458  0.010060
# 4367           0.012601  0.010060
# 4368           0.012501  0.008048
# 4369           0.010456  0.012072
#
# [4370 rows x 2 columns]

# %%
plt.plot(test_results['Train Predictions'][:300], label='Predicted Values')
plt.plot(test_results['Actual'][:300], label='True Values')
plt.legend()
plt.show()

# %%
rmse = sqrt(mse(y_test, test_predictions))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.02216

# %% [markdown]
# This is just a plot on the standardised values, lets have a look at the inverse and compare results on the actual scale.

# %%
# Assume scaler is the same scaler used to normalize the data
# Reverse the scaling for both predictions and actual values

# Inverse transform for predicted values
test_predictions_scaled = scaler.inverse_transform(test_predictions.reshape(-1, 1)).flatten()

# Inverse transform for actual values (y_test)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()

# Create a DataFrame with actual vs predicted values
test_results = pd.DataFrame(data={'Train Predictions': test_predictions_scaled,
                                  'Actual': y_test_scaled})

# Print the results for a quick check
print(test_results.head())

# Plot the results
plt.figure(figsize=(10,6))
plt.plot(test_results['Train Predictions'][:300], label='Predicted Values')
plt.plot(test_results['Actual'][:300], label='True Values')
plt.legend()
plt.title('Predicted vs Actual Values (Inverse Transformed)')
plt.xlabel('Time Steps')
plt.ylabel('Pollution Level (Original Scale)')
plt.show()
# Out:
#    Train Predictions  Actual
# 0         114.181000   101.0
# 1         101.306412   111.0
# 2         111.281639   110.0
# 3         109.858734   134.0
# 4         133.739929   169.0

# %%
rmse = sqrt(mse(y_test_scaled, test_predictions_scaled))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 22.030

# %% [markdown]
# ## Batch size

# %% [markdown]
# Taking the number of epochs needed to be roughly 20, we will now test batch size to identify optimal CPU performance agaibst root mean square error.

# %%
batch_sizes=[16,32,64,128,256]
results = {"batch_size": [], "rmse":[], "cpu_time": []}

# %%
for batch_size in batch_sizes:
        model.set_weights(initial_weights)
        start_time = time.time()
        model.fit(X_train, y_train, epochs=30, batch_size=batch_size, validation_data=(X_test, y_test), shuffle=False)
        cpu_time = time.time() - start_time
        CPU_scores = model.evaluate(X_test, y_test)
        results["batch_size"].append(batch_size)
        results["rmse"].append(CPU_scores[1])
        results["cpu_time"].append(cpu_time)
# Out:
# Epoch 1/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0014 - root_mean_squared_error: 0.0370 - val_loss: 5.4014e-04 - val_root_mean_squared_error: 0.0232
# Epoch 2/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0010 - root_mean_squared_error: 0.0315 - val_loss: 5.4017e-04 - val_root_mean_squared_error: 0.0232
# Epoch 3/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0010 - root_mean_squared_error: 0.0313 - val_loss: 5.4217e-04 - val_root_mean_squared_error: 0.0233
# Epoch 4/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.9160e-04 - root_mean_squared_error: 0.0312 - val_loss: 5.4310e-04 - val_root_mean_squared_error: 0.0233
# Epoch 5/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.8171e-04 - root_mean_squared_error: 0.0310 - val_loss: 5.4321e-04 - val_root_mean_squared_error: 0.0233
# Epoch 6/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.7391e-04 - root_mean_squared_error: 0.0309 - val_loss: 5.4258e-04 - val_root_mean_squared_error: 0.0233
# Epoch 7/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.6790e-04 - root_mean_squared_error: 0.0308 - val_loss: 5.4156e-04 - val_root_mean_squared_error: 0.0233
# Epoch 8/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.6309e-04 - root_mean_squared_error: 0.0307 - val_loss: 5.4043e-04 - val_root_mean_squared_error: 0.0232
# Epoch 9/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.5923e-04 - root_mean_squared_error: 0.0307 - val_loss: 5.3932e-04 - val_root_mean_squared_error: 0.0232
# Epoch 10/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.5597e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.3825e-04 - val_root_mean_squared_error: 0.0232
# Epoch 11/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.5317e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.3717e-04 - val_root_mean_squared_error: 0.0232
# Epoch 12/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.5078e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.3617e-04 - val_root_mean_squared_error: 0.0232
# Epoch 13/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.4866e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.3531e-04 - val_root_mean_squared_error: 0.0231
# Epoch 14/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.4672e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.3445e-04 - val_root_mean_squared_error: 0.0231
# Epoch 15/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.4495e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.3352e-04 - val_root_mean_squared_error: 0.0231
# Epoch 16/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.4335e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.3251e-04 - val_root_mean_squared_error: 0.0231
# Epoch 17/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.4191e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.3150e-04 - val_root_mean_squared_error: 0.0231
# Epoch 18/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.4057e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.3055e-04 - val_root_mean_squared_error: 0.0230
# Epoch 19/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 9.3935e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.2973e-04 - val_root_mean_squared_error: 0.0230
# Epoch 20/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.3816e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.2879e-04 - val_root_mean_squared_error: 0.0230
# Epoch 21/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.3702e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.2775e-04 - val_root_mean_squared_error: 0.0230
# Epoch 22/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - loss: 9.3595e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.2687e-04 - val_root_mean_squared_error: 0.0230
# Epoch 23/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 9.3492e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.2605e-04 - val_root_mean_squared_error: 0.0229
# Epoch 24/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.3389e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.2514e-04 - val_root_mean_squared_error: 0.0229
# Epoch 25/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.3288e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.2419e-04 - val_root_mean_squared_error: 0.0229
# Epoch 26/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.3191e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.2335e-04 - val_root_mean_squared_error: 0.0229
# Epoch 27/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.3098e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.2261e-04 - val_root_mean_squared_error: 0.0229
# Epoch 28/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.3007e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.2194e-04 - val_root_mean_squared_error: 0.0228
# Epoch 29/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.2914e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.2134e-04 - val_root_mean_squared_error: 0.0228
# Epoch 30/30
# 2464/2464 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 9.2814e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.2074e-04 - val_root_mean_squared_error: 0.0228
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 3.1637e-04 - root_mean_squared_error: 0.0175
# Epoch 1/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0016 - root_mean_squared_error: 0.0396 - val_loss: 5.2945e-04 - val_root_mean_squared_error: 0.0230
# Epoch 2/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.7799e-04 - root_mean_squared_error: 0.0310 - val_loss: 5.0647e-04 - val_root_mean_squared_error: 0.0225
# Epoch 3/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.9787e-04 - root_mean_squared_error: 0.0312 - val_loss: 5.0729e-04 - val_root_mean_squared_error: 0.0225
# Epoch 4/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.9477e-04 - root_mean_squared_error: 0.0312 - val_loss: 5.0909e-04 - val_root_mean_squared_error: 0.0226
# Epoch 5/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.8832e-04 - root_mean_squared_error: 0.0311 - val_loss: 5.1046e-04 - val_root_mean_squared_error: 0.0226
# Epoch 6/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.8199e-04 - root_mean_squared_error: 0.0310 - val_loss: 5.1147e-04 - val_root_mean_squared_error: 0.0226
# Epoch 7/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.7626e-04 - root_mean_squared_error: 0.0309 - val_loss: 5.1232e-04 - val_root_mean_squared_error: 0.0226
# Epoch 8/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.7130e-04 - root_mean_squared_error: 0.0309 - val_loss: 5.1287e-04 - val_root_mean_squared_error: 0.0226
# Epoch 9/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.6715e-04 - root_mean_squared_error: 0.0308 - val_loss: 5.1320e-04 - val_root_mean_squared_error: 0.0227
# Epoch 10/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.6348e-04 - root_mean_squared_error: 0.0307 - val_loss: 5.1336e-04 - val_root_mean_squared_error: 0.0227
# Epoch 11/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.6026e-04 - root_mean_squared_error: 0.0307 - val_loss: 5.1344e-04 - val_root_mean_squared_error: 0.0227
# Epoch 12/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.5737e-04 - root_mean_squared_error: 0.0307 - val_loss: 5.1334e-04 - val_root_mean_squared_error: 0.0227
# Epoch 13/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.5475e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.1321e-04 - val_root_mean_squared_error: 0.0227
# Epoch 14/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.5237e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.1301e-04 - val_root_mean_squared_error: 0.0226
# Epoch 15/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.5021e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.1278e-04 - val_root_mean_squared_error: 0.0226
# Epoch 16/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.4818e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.1256e-04 - val_root_mean_squared_error: 0.0226
# Epoch 17/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.4626e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.1228e-04 - val_root_mean_squared_error: 0.0226
# Epoch 18/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 9.4454e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.1202e-04 - val_root_mean_squared_error: 0.0226
# Epoch 19/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.4292e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.1175e-04 - val_root_mean_squared_error: 0.0226
# Epoch 20/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.4137e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.1147e-04 - val_root_mean_squared_error: 0.0226
# Epoch 21/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.3991e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.1122e-04 - val_root_mean_squared_error: 0.0226
# Epoch 22/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.3851e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.1099e-04 - val_root_mean_squared_error: 0.0226
# Epoch 23/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.3716e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.1078e-04 - val_root_mean_squared_error: 0.0226
# Epoch 24/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.3590e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.1057e-04 - val_root_mean_squared_error: 0.0226
# Epoch 25/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.3470e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.1036e-04 - val_root_mean_squared_error: 0.0226
# Epoch 26/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.3354e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.1013e-04 - val_root_mean_squared_error: 0.0226
# Epoch 27/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.3242e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0989e-04 - val_root_mean_squared_error: 0.0226
# Epoch 28/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.3134e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0964e-04 - val_root_mean_squared_error: 0.0226
# Epoch 29/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.3027e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.0938e-04 - val_root_mean_squared_error: 0.0226
# Epoch 30/30
# 1232/1232 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 9.2921e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.0915e-04 - val_root_mean_squared_error: 0.0226
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 3.0546e-04 - root_mean_squared_error: 0.0172
# Epoch 1/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0017 - root_mean_squared_error: 0.0411 - val_loss: 5.7009e-04 - val_root_mean_squared_error: 0.0239
# Epoch 2/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7237e-04 - root_mean_squared_error: 0.0310 - val_loss: 5.0504e-04 - val_root_mean_squared_error: 0.0225
# Epoch 3/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7132e-04 - root_mean_squared_error: 0.0309 - val_loss: 4.9531e-04 - val_root_mean_squared_error: 0.0223
# Epoch 4/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7757e-04 - root_mean_squared_error: 0.0309 - val_loss: 4.9425e-04 - val_root_mean_squared_error: 0.0222
# Epoch 5/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7573e-04 - root_mean_squared_error: 0.0309 - val_loss: 4.9458e-04 - val_root_mean_squared_error: 0.0222
# Epoch 6/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7190e-04 - root_mean_squared_error: 0.0308 - val_loss: 4.9488e-04 - val_root_mean_squared_error: 0.0222
# Epoch 7/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.6773e-04 - root_mean_squared_error: 0.0308 - val_loss: 4.9500e-04 - val_root_mean_squared_error: 0.0222
# Epoch 8/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.6366e-04 - root_mean_squared_error: 0.0307 - val_loss: 4.9502e-04 - val_root_mean_squared_error: 0.0222
# Epoch 9/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.5983e-04 - root_mean_squared_error: 0.0307 - val_loss: 4.9500e-04 - val_root_mean_squared_error: 0.0222
# Epoch 10/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.5629e-04 - root_mean_squared_error: 0.0306 - val_loss: 4.9500e-04 - val_root_mean_squared_error: 0.0222
# Epoch 11/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.5311e-04 - root_mean_squared_error: 0.0306 - val_loss: 4.9490e-04 - val_root_mean_squared_error: 0.0222
# Epoch 12/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.5020e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.9487e-04 - val_root_mean_squared_error: 0.0222
# Epoch 13/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.4759e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.9485e-04 - val_root_mean_squared_error: 0.0222
# Epoch 14/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.4524e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.9486e-04 - val_root_mean_squared_error: 0.0222
# Epoch 15/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.4309e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.9484e-04 - val_root_mean_squared_error: 0.0222
# Epoch 16/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.4113e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.9484e-04 - val_root_mean_squared_error: 0.0222
# Epoch 17/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3934e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.9471e-04 - val_root_mean_squared_error: 0.0222
# Epoch 18/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3769e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.9455e-04 - val_root_mean_squared_error: 0.0222
# Epoch 19/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3617e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.9442e-04 - val_root_mean_squared_error: 0.0222
# Epoch 20/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3473e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.9436e-04 - val_root_mean_squared_error: 0.0222
# Epoch 21/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3340e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.9419e-04 - val_root_mean_squared_error: 0.0222
# Epoch 22/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3215e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.9405e-04 - val_root_mean_squared_error: 0.0222
# Epoch 23/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3097e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.9391e-04 - val_root_mean_squared_error: 0.0222
# Epoch 24/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.2986e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.9379e-04 - val_root_mean_squared_error: 0.0222
# Epoch 25/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 9.2882e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.9368e-04 - val_root_mean_squared_error: 0.0222
# Epoch 26/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.2779e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.9359e-04 - val_root_mean_squared_error: 0.0222
# Epoch 27/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.2679e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.9354e-04 - val_root_mean_squared_error: 0.0222
# Epoch 28/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.2587e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.9342e-04 - val_root_mean_squared_error: 0.0222
# Epoch 29/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.2500e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.9329e-04 - val_root_mean_squared_error: 0.0222
# Epoch 30/30
# 616/616 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.2414e-04 - root_mean_squared_error: 0.0301 - val_loss: 4.9320e-04 - val_root_mean_squared_error: 0.0222
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - loss: 2.9321e-04 - root_mean_squared_error: 0.0169
# Epoch 1/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0022 - root_mean_squared_error: 0.0457 - val_loss: 6.3225e-04 - val_root_mean_squared_error: 0.0251
# Epoch 2/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0010 - root_mean_squared_error: 0.0316 - val_loss: 5.3379e-04 - val_root_mean_squared_error: 0.0231
# Epoch 3/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.5727e-04 - root_mean_squared_error: 0.0307 - val_loss: 5.0276e-04 - val_root_mean_squared_error: 0.0224
# Epoch 4/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.5604e-04 - root_mean_squared_error: 0.0307 - val_loss: 4.9297e-04 - val_root_mean_squared_error: 0.0222
# Epoch 5/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.5998e-04 - root_mean_squared_error: 0.0307 - val_loss: 4.8966e-04 - val_root_mean_squared_error: 0.0221
# Epoch 6/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.6064e-04 - root_mean_squared_error: 0.0307 - val_loss: 4.8829e-04 - val_root_mean_squared_error: 0.0221
# Epoch 7/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.5938e-04 - root_mean_squared_error: 0.0307 - val_loss: 4.8761e-04 - val_root_mean_squared_error: 0.0221
# Epoch 8/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.5746e-04 - root_mean_squared_error: 0.0306 - val_loss: 4.8724e-04 - val_root_mean_squared_error: 0.0221
# Epoch 9/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.5537e-04 - root_mean_squared_error: 0.0306 - val_loss: 4.8702e-04 - val_root_mean_squared_error: 0.0221
# Epoch 10/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.5329e-04 - root_mean_squared_error: 0.0306 - val_loss: 4.8689e-04 - val_root_mean_squared_error: 0.0221
# Epoch 11/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.5127e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.8680e-04 - val_root_mean_squared_error: 0.0221
# Epoch 12/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.4933e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.8674e-04 - val_root_mean_squared_error: 0.0221
# Epoch 13/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.4748e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.8669e-04 - val_root_mean_squared_error: 0.0221
# Epoch 14/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.4570e-04 - root_mean_squared_error: 0.0305 - val_loss: 4.8664e-04 - val_root_mean_squared_error: 0.0221
# Epoch 15/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.4400e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.8660e-04 - val_root_mean_squared_error: 0.0221
# Epoch 16/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 9.4238e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.8657e-04 - val_root_mean_squared_error: 0.0221
# Epoch 17/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.4083e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.8655e-04 - val_root_mean_squared_error: 0.0221
# Epoch 18/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.3936e-04 - root_mean_squared_error: 0.0304 - val_loss: 4.8653e-04 - val_root_mean_squared_error: 0.0221
# Epoch 19/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.3796e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.8653e-04 - val_root_mean_squared_error: 0.0221
# Epoch 20/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.3662e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.8653e-04 - val_root_mean_squared_error: 0.0221
# Epoch 21/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.3535e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.8653e-04 - val_root_mean_squared_error: 0.0221
# Epoch 22/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.3415e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.8654e-04 - val_root_mean_squared_error: 0.0221
# Epoch 23/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.3301e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.8655e-04 - val_root_mean_squared_error: 0.0221
# Epoch 24/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.3192e-04 - root_mean_squared_error: 0.0303 - val_loss: 4.8656e-04 - val_root_mean_squared_error: 0.0221
# Epoch 25/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.3089e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.8657e-04 - val_root_mean_squared_error: 0.0221
# Epoch 26/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.2990e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.8659e-04 - val_root_mean_squared_error: 0.0221
# Epoch 27/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.2897e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.8660e-04 - val_root_mean_squared_error: 0.0221
# Epoch 28/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.2807e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.8661e-04 - val_root_mean_squared_error: 0.0221
# Epoch 29/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.2722e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.8663e-04 - val_root_mean_squared_error: 0.0221
# Epoch 30/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.2639e-04 - root_mean_squared_error: 0.0302 - val_loss: 4.8664e-04 - val_root_mean_squared_error: 0.0221
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - loss: 2.8889e-04 - root_mean_squared_error: 0.0168
# Epoch 1/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0027 - root_mean_squared_error: 0.0503 - val_loss: 8.4874e-04 - val_root_mean_squared_error: 0.0291
# Epoch 2/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.0011 - root_mean_squared_error: 0.0334 - val_loss: 6.4042e-04 - val_root_mean_squared_error: 0.0253
# Epoch 3/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.9341e-04 - root_mean_squared_error: 0.0314 - val_loss: 5.7279e-04 - val_root_mean_squared_error: 0.0239
# Epoch 4/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.5657e-04 - root_mean_squared_error: 0.0307 - val_loss: 5.4417e-04 - val_root_mean_squared_error: 0.0233
# Epoch 5/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.4961e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.3069e-04 - val_root_mean_squared_error: 0.0230
# Epoch 6/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.5082e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.2346e-04 - val_root_mean_squared_error: 0.0229
# Epoch 7/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.5203e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.1900e-04 - val_root_mean_squared_error: 0.0228
# Epoch 8/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.5199e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.1615e-04 - val_root_mean_squared_error: 0.0227
# Epoch 9/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.5111e-04 - root_mean_squared_error: 0.0306 - val_loss: 5.1421e-04 - val_root_mean_squared_error: 0.0227
# Epoch 10/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.4982e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.1280e-04 - val_root_mean_squared_error: 0.0226
# Epoch 11/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.4836e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.1169e-04 - val_root_mean_squared_error: 0.0226
# Epoch 12/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.4686e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.1077e-04 - val_root_mean_squared_error: 0.0226
# Epoch 13/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.4536e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.1000e-04 - val_root_mean_squared_error: 0.0226
# Epoch 14/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.4389e-04 - root_mean_squared_error: 0.0305 - val_loss: 5.0933e-04 - val_root_mean_squared_error: 0.0226
# Epoch 15/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.4246e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.0874e-04 - val_root_mean_squared_error: 0.0226
# Epoch 16/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.4107e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.0823e-04 - val_root_mean_squared_error: 0.0225
# Epoch 17/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.3972e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.0778e-04 - val_root_mean_squared_error: 0.0225
# Epoch 18/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.3841e-04 - root_mean_squared_error: 0.0304 - val_loss: 5.0739e-04 - val_root_mean_squared_error: 0.0225
# Epoch 19/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.3714e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0704e-04 - val_root_mean_squared_error: 0.0225
# Epoch 20/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.3591e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0674e-04 - val_root_mean_squared_error: 0.0225
# Epoch 21/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.3473e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0649e-04 - val_root_mean_squared_error: 0.0225
# Epoch 22/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.3358e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0627e-04 - val_root_mean_squared_error: 0.0225
# Epoch 23/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.3247e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0609e-04 - val_root_mean_squared_error: 0.0225
# Epoch 24/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.3140e-04 - root_mean_squared_error: 0.0303 - val_loss: 5.0594e-04 - val_root_mean_squared_error: 0.0225
# Epoch 25/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 9.3036e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.0583e-04 - val_root_mean_squared_error: 0.0225
# Epoch 26/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.2937e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.0575e-04 - val_root_mean_squared_error: 0.0225
# Epoch 27/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.2841e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.0569e-04 - val_root_mean_squared_error: 0.0225
# Epoch 28/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.2748e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.0567e-04 - val_root_mean_squared_error: 0.0225
# Epoch 29/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.2659e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.0569e-04 - val_root_mean_squared_error: 0.0225
# Epoch 30/30
# 154/154 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 9.2573e-04 - root_mean_squared_error: 0.0302 - val_loss: 5.0573e-04 - val_root_mean_squared_error: 0.0225
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 3.0682e-04 - root_mean_squared_error: 0.0173

# %% [markdown]
# Now we will use these results to compare batch size with training time and rsme

# %%
fig, ax1 = plt.subplots()

# Plot CPU training time
ax1.set_xlabel('Batch Size')
ax1.set_ylabel('CPU Training Time (seconds)', color='tab:blue')
ax1.plot(results["batch_size"], results["cpu_time"], color='tab:blue', marker='o', label='CPU Training Time')
ax1.tick_params(axis='y', labelcolor='tab:blue')

# Create second y-axis to plot RMSE
ax2 = ax1.twinx()
ax2.set_ylabel('RMSE', color='tab:orange')
ax2.plot(results["batch_size"], results["rmse"], color='tab:orange', marker='s', label='RMSE')
ax2.tick_params(axis='y', labelcolor='tab:orange')

# Show grid and title
plt.title('Comparison of CPU Training Time and RMSE for Different Batch Sizes')
ax1.grid(True)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# As batch size 128 outputted the second best training time and best RMSE so we will use this batch size going forward. Any higher batch size will likely underfit the data set without having too much additional benefit to training time, as we can see with RSME increasing at 256 batch size.

# %% [markdown]
# ## Dropout layer

# %% [markdown]
# We will explore the use of using a dropout layer in our model to prevent overfitting. Based on our current results, the data does not seem to be overfitting as our test rsme has been lower than our training rsme so far, and the compelxity of our model is much lower due to it being univariate. However this process is a common method in LSTM modelling, so I will explore the useful of it.
#
# A dropout layer is a regularization technique in neural networks, input and recurrent connections to LSTM units are probabilistically excluded from activation forcing the to learn new patterns and generalise better to unseen data.

# %%
model.set_weights(initial_weights)
model.add(Dropout(0.2))

start_time = time.time() 
history = model.fit(
    X_train, y_train, 
    epochs=30,                   
    batch_size=128,                
    validation_data=(X_test, y_test))

print("Training Time: ", time.time() - start_time)
# Out:
# Epoch 1/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0022 - root_mean_squared_error: 0.0457 - val_loss: 6.3472e-04 - val_root_mean_squared_error: 0.0252
# Epoch 2/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 8.6728e-04 - root_mean_squared_error: 0.0294 - val_loss: 5.3737e-04 - val_root_mean_squared_error: 0.0232
# Epoch 3/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.8874e-04 - root_mean_squared_error: 0.0281 - val_loss: 5.0898e-04 - val_root_mean_squared_error: 0.0226
# Epoch 4/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.6817e-04 - root_mean_squared_error: 0.0277 - val_loss: 5.0099e-04 - val_root_mean_squared_error: 0.0224
# Epoch 5/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.6138e-04 - root_mean_squared_error: 0.0276 - val_loss: 4.9789e-04 - val_root_mean_squared_error: 0.0223
# Epoch 6/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 7.5817e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9628e-04 - val_root_mean_squared_error: 0.0223
# Epoch 7/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5632e-04 - root_mean_squared_error: 0.0275 - val_loss: 4.9531e-04 - val_root_mean_squared_error: 0.0223
# Epoch 8/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5515e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9468e-04 - val_root_mean_squared_error: 0.0222
# Epoch 9/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5438e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9426e-04 - val_root_mean_squared_error: 0.0222
# Epoch 10/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5384e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9397e-04 - val_root_mean_squared_error: 0.0222
# Epoch 11/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5346e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9378e-04 - val_root_mean_squared_error: 0.0222
# Epoch 12/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5318e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9364e-04 - val_root_mean_squared_error: 0.0222
# Epoch 13/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5296e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9354e-04 - val_root_mean_squared_error: 0.0222
# Epoch 14/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5278e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9346e-04 - val_root_mean_squared_error: 0.0222
# Epoch 15/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5262e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9339e-04 - val_root_mean_squared_error: 0.0222
# Epoch 16/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5250e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9334e-04 - val_root_mean_squared_error: 0.0222
# Epoch 17/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5239e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9328e-04 - val_root_mean_squared_error: 0.0222
# Epoch 18/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5230e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9322e-04 - val_root_mean_squared_error: 0.0222
# Epoch 19/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5223e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9316e-04 - val_root_mean_squared_error: 0.0222
# Epoch 20/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5216e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9311e-04 - val_root_mean_squared_error: 0.0222
# Epoch 21/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5210e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9306e-04 - val_root_mean_squared_error: 0.0222
# Epoch 22/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5204e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9303e-04 - val_root_mean_squared_error: 0.0222
# Epoch 23/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5199e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9300e-04 - val_root_mean_squared_error: 0.0222
# Epoch 24/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5193e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9298e-04 - val_root_mean_squared_error: 0.0222
# Epoch 25/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5187e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9296e-04 - val_root_mean_squared_error: 0.0222
# Epoch 26/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5181e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9295e-04 - val_root_mean_squared_error: 0.0222
# Epoch 27/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5174e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9295e-04 - val_root_mean_squared_error: 0.0222
# Epoch 28/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5168e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9297e-04 - val_root_mean_squared_error: 0.0222
# Epoch 29/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5161e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9297e-04 - val_root_mean_squared_error: 0.0222
# Epoch 30/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.5154e-04 - root_mean_squared_error: 0.0274 - val_loss: 4.9295e-04 - val_root_mean_squared_error: 0.0222
# Training Time:  34.17853784561157

# %%
test_predictions = model.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Train Predictions': test_predictions,
                                  'Actual':y_test.flatten()})
print(test_results)
# Out:
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step
#       Train Predictions    Actual
# 0              0.114099  0.101610
# 1              0.101073  0.111670
# 2              0.110687  0.110664
# 3              0.109696  0.134809
# 4              0.133402  0.170020
# ...                 ...       ...
# 4365           0.012805  0.008048
# 4366           0.010816  0.010060
# 4367           0.012828  0.010060
# 4368           0.012843  0.008048
# 4369           0.010789  0.012072
#
# [4370 rows x 2 columns]

# %%
# Assume scaler is the same scaler used to normalize the data
# Reverse the scaling for both predictions and actual values

# Inverse transform for predicted values
test_predictions_scaled = scaler.inverse_transform(test_predictions.reshape(-1, 1)).flatten()

# Inverse transform for actual values (y_test)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()

# Create a DataFrame with actual vs predicted values
test_results = pd.DataFrame(data={'Train Predictions': test_predictions_scaled,
                                  'Actual': y_test_scaled})

# Print the results for a quick check
print(test_results.head())

# Plot the results
plt.figure(figsize=(10,6))
plt.plot(test_results['Train Predictions'][:300], label='Predicted Values')
plt.plot(test_results['Actual'][:300], label='True Values')
plt.legend()
plt.title('Predicted vs Actual Values (Inverse Transformed)')
plt.xlabel('Time Steps')
plt.ylabel('Pollution Level (Original Scale)')
plt.show()
# Out:
#    Train Predictions  Actual
# 0         113.414673   101.0
# 1         100.466545   111.0
# 2         110.023064   110.0
# 3         109.038086   134.0
# 4         132.602020   169.0

# %%
rmse = sqrt(mse(y_test, test_predictions))
print('Test RMSE: %.5f' % rmse)
# Out:
# Test RMSE: 0.02220

# %%
rmse = sqrt(mse(y_test_scaled, test_predictions_scaled))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 22.069

# %% [markdown]
# The Dropout layer slightly increased our test RSME loss, indicating perhaps that the model was not overfitting.

# %% [markdown]
# We have a low test RMSE of 22.069 and training time of 34 seconds.

# %% [markdown]
# ## Stacked LSTM

# %%
stacked_LSTM = Sequential()
stacked_LSTM.add(Input(shape =(X_train.shape[1], 1)))
stacked_LSTM.add(LSTM(32,return_sequences=True))
stacked_LSTM.add(Dropout(0.2)) 
stacked_LSTM.add(LSTM(16, return_sequences=False))
stacked_LSTM.add(Dense(1)) 

stacked_LSTM.compile(optimizer=Adam(learning_rate = 0.001), loss='mse', metrics = [RootMeanSquaredError()])

start_time = time.time()

history = stacked_LSTM.fit(
    X_train, y_train, 
    epochs=30,                  
    batch_size=128,                
    validation_data=(X_test, y_test)
)

print("Training Time: ", time.time() - start_time)

plt.figure(figsize=(15,6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

test_predictions = model.predict(X_test).flatten()
test_results = pd.DataFrame(data={'Train Predictions': test_predictions,
                                  'Actual':y_test.flatten()})

test_predictions_scaled = scaler.inverse_transform(test_predictions.reshape(-1, 1)).flatten()

# Inverse transform for actual values (y_test)
y_test_scaled = scaler.inverse_transform(y_test.reshape(-1, 1)).flatten()

# Create a DataFrame with actual vs predicted values
test_results = pd.DataFrame(data={'Train Predictions': test_predictions_scaled,
                                  'Actual': y_test_scaled})

# Print the results for a quick check
print(test_results.head())

# Plot the results
plt.figure(figsize=(10,6))
plt.plot(test_results['Train Predictions'][:400], label='Predicted Values')
plt.plot(test_results['Actual'][:400], label='True Values')
plt.legend()
plt.title('Predicted vs Actual Values (Inverse Transformed)')
plt.xlabel('Time Steps')
plt.ylabel('Pollution Level (Original Scale)')
plt.show()
# Out:
# Epoch 1/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.0044 - root_mean_squared_error: 0.0644 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0347
# Epoch 2/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0015 - root_mean_squared_error: 0.0383 - val_loss: 7.7247e-04 - val_root_mean_squared_error: 0.0278
# Epoch 3/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0011 - root_mean_squared_error: 0.0327 - val_loss: 6.0541e-04 - val_root_mean_squared_error: 0.0246
# Epoch 4/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 9.0131e-04 - root_mean_squared_error: 0.0300 - val_loss: 5.4951e-04 - val_root_mean_squared_error: 0.0234
# Epoch 5/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.5195e-04 - root_mean_squared_error: 0.0292 - val_loss: 5.3984e-04 - val_root_mean_squared_error: 0.0232
# Epoch 6/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.3788e-04 - root_mean_squared_error: 0.0289 - val_loss: 5.2552e-04 - val_root_mean_squared_error: 0.0229
# Epoch 7/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.1219e-04 - root_mean_squared_error: 0.0285 - val_loss: 5.1100e-04 - val_root_mean_squared_error: 0.0226
# Epoch 8/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.1319e-04 - root_mean_squared_error: 0.0285 - val_loss: 5.0619e-04 - val_root_mean_squared_error: 0.0225
# Epoch 9/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 8.1888e-04 - root_mean_squared_error: 0.0286 - val_loss: 5.0377e-04 - val_root_mean_squared_error: 0.0224
# Epoch 10/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.0319e-04 - root_mean_squared_error: 0.0283 - val_loss: 5.0287e-04 - val_root_mean_squared_error: 0.0224
# Epoch 11/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.0850e-04 - root_mean_squared_error: 0.0284 - val_loss: 5.0689e-04 - val_root_mean_squared_error: 0.0225
# Epoch 12/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.9101e-04 - root_mean_squared_error: 0.0281 - val_loss: 4.9701e-04 - val_root_mean_squared_error: 0.0223
# Epoch 13/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 8.0361e-04 - root_mean_squared_error: 0.0283 - val_loss: 4.9874e-04 - val_root_mean_squared_error: 0.0223
# Epoch 14/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 8.0176e-04 - root_mean_squared_error: 0.0283 - val_loss: 4.9827e-04 - val_root_mean_squared_error: 0.0223
# Epoch 15/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.8906e-04 - root_mean_squared_error: 0.0281 - val_loss: 5.0009e-04 - val_root_mean_squared_error: 0.0224
# Epoch 16/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.9832e-04 - root_mean_squared_error: 0.0282 - val_loss: 4.9581e-04 - val_root_mean_squared_error: 0.0223
# Epoch 17/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.9239e-04 - root_mean_squared_error: 0.0281 - val_loss: 4.9498e-04 - val_root_mean_squared_error: 0.0222
# Epoch 18/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.9094e-04 - root_mean_squared_error: 0.0281 - val_loss: 4.9404e-04 - val_root_mean_squared_error: 0.0222
# Epoch 19/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.9187e-04 - root_mean_squared_error: 0.0281 - val_loss: 4.9506e-04 - val_root_mean_squared_error: 0.0222
# Epoch 20/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.9699e-04 - root_mean_squared_error: 0.0282 - val_loss: 4.9484e-04 - val_root_mean_squared_error: 0.0222
# Epoch 21/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.8949e-04 - root_mean_squared_error: 0.0281 - val_loss: 4.9251e-04 - val_root_mean_squared_error: 0.0222
# Epoch 22/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.8498e-04 - root_mean_squared_error: 0.0280 - val_loss: 4.9383e-04 - val_root_mean_squared_error: 0.0222
# Epoch 23/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.8368e-04 - root_mean_squared_error: 0.0280 - val_loss: 4.9684e-04 - val_root_mean_squared_error: 0.0223
# Epoch 24/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.8096e-04 - root_mean_squared_error: 0.0279 - val_loss: 4.9198e-04 - val_root_mean_squared_error: 0.0222
# Epoch 25/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.8821e-04 - root_mean_squared_error: 0.0280 - val_loss: 4.9232e-04 - val_root_mean_squared_error: 0.0222
# Epoch 26/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 7.8713e-04 - root_mean_squared_error: 0.0280 - val_loss: 4.9311e-04 - val_root_mean_squared_error: 0.0222
# Epoch 27/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 7.8618e-04 - root_mean_squared_error: 0.0280 - val_loss: 4.9260e-04 - val_root_mean_squared_error: 0.0222
# Epoch 28/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.8609e-04 - root_mean_squared_error: 0.0280 - val_loss: 4.8966e-04 - val_root_mean_squared_error: 0.0221
# Epoch 29/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.8388e-04 - root_mean_squared_error: 0.0280 - val_loss: 4.9057e-04 - val_root_mean_squared_error: 0.0221
# Epoch 30/30
# 308/308 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 7.8347e-04 - root_mean_squared_error: 0.0280 - val_loss: 4.8905e-04 - val_root_mean_squared_error: 0.0221
# Training Time:  43.77677798271179
# 137/137 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step
#    Train Predictions  Actual
# 0         113.414673   101.0
# 1         100.466545   111.0
# 2         110.023064   110.0
# 3         109.038086   134.0
# 4         132.602020   169.0

# %%
rmse = sqrt(mse(y_test_scaled, test_predictions_scaled))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 22.069

# %% [markdown]
# Running a stacked model only increased training time whilst the RSME remained the same. I discuss why this may be the case in my conclusion.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this notebook, I have explored the use of a single-variate LSTM model to assess whether we can reduce computational costs without sacrificing model performance. The results so far are very good, with the model performing well and achieving a low runtime, despite the lack of GPU support. This is encouraging for the scalability of our model, especially when considering larger datasets. When comparing the single-variate model with the multivariate model in future work, we will assess whether the dimensionality reduction was appropriate by identifying and potentially removing unnecessary noise.
#
# In Matt's notebook, we will further evaluate how the LSTM model compares to the multivariate approach using the GPU support available through `tensorflow-metal`.
#
# One of the key disadvantages of using LSTM models is their sequential nature, where each epoch is processed one at a time, limiting the potential for parallelization. For example, PySpark is not optimized for deep learning tasks, and therefore may not be well-suited for scaling our LSTM model. However, strategies such as minimizing the number of epochs, ensuring minimal training loss, and using large batch sizes (while avoiding overfitting) are essential for reducing training time, which were all used in this notebook.

# %% [markdown]
# Based on our EDA on partial autocorrelation, it suggested that only the previous time step is useful information to predict future values. So, when we used a stacked LSTM the one with more layers with the one that seemed to have same performance but its training time was higher, this could be just because we are adding unnecessary complexity on top of the model. The additional layers are made to capture long-range dependencies and complexity which may be unnecessary for this simple univariate data that doesn't seem to have long-range dependencies. Moreover, having `return_sequences=True` on the LSTM layers are not necessary, since it would keep all the hidden states. If the predictions only require the previous time step, this could slow down training and increase memory usage.
#
# For my model, adding complexity to the model for better loss performance may not be ideal but this might be useful for Matt with his multivariate model.
#
#
# On the contray, the model also appears to have some bias toward the mean (when looking at the extreme values of the graphs), which could be a sign of underfitting. This could be problematic when applying the model in the real world, as predicting high levels of pollution is crucial for prevention, rather than having an overly conservative model. This mean-bias could be due to a number of factors. Perhaps because we only have one feature, the model doesn't have enough data to capture the temporal dependencies, or there is a lack of variability or patterns available in the data. If we were to use only pollution data and no other metrics, one approach could be to include lag features (thus making the model multivariate). Another consideration could be adjusting the sequence length to be longer, e.g a day/24 hours. While this may seem counterintuitive based on our EDA of partial autocorrelation, it could allow the model to capture a longer range of temporal dependencies which may have been missed. This suggestion is supported by the EDA on autocorrelation instead, which had correlation of around 0.5 on time step t + 24. Also, adjusting the loss function from the mean squared error (which minimizes distance from the mean) to any other loss function could potentially solve the problem of model biasing towards the mean. In the pursuit of reducing training time, increasing the batch size might have had a negative effect with regard to underfitting.

# %% [markdown]
# ### Other Resources

# %% [markdown]
# Moving window validation: https://medium.com/@TheDataScience-ProF/understanding-timeseriessplit-cross-validation-for-time-series-data-4c232cc4f844#:~:text=TimeSeriesSplit%20Cross%2DValidation%20Overview&text=The%20dataset%20is%20split%20into,and%20evaluated%20on%20future%20data.
#
# considerations for optimising lstm performance: https://medium.com/@yousufdata/6-tips-to-tweak-your-lstm-bilstm-15fd02685c8#:~:text=Your%20LSTM%20should%20always%20have,error%20in%20your%20neural%20network.
#
# considerations for optimising training time: https://towardsdatascience.com/how-to-reduce-the-training-time-of-your-neural-network-from-hours-to-minutes-fe7533a3eec5
#
# pyspark suitability for lstm: https://datascience.stackexchange.com/questions/53089/how-to-implement-lstm-with-spark
#
# return_sequences : https://eitca.org/artificial-intelligence/eitc-ai-tff-tensorflow-fundamentals/natural-language-processing-with-tensorflow/long-short-term-memory-for-nlp/examination-review-long-short-term-memory-for-nlp/what-is-the-significance-of-setting-the-return_sequences-parameter-to-true-when-stacking-multiple-lstm-layers/
